# %%
from IPython.core.display import display, HTML

display(HTML("<style>.jp-Cell-inputWrapper { overflow-x: auto; }</style>"))
# Out:
# /var/folders/wl/8jx7ngdj365dkn33jz1rs3180000gn/T/ipykernel_9390/4272499723.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.jp-Cell-inputWrapper { overflow-x: auto; }</style>

# %%
import pandas as pd
import numpy as np
from faker import Faker
import random

# Initialize Faker for generating realistic-looking data
fake = Faker('en_US')

# Number of clients to generate
num_clients = 5000

# Median household income in the USA 2023 was around $80,610 (using a rounded figure)
MEDIAN_HOUSEHOLD_INCOME_2023 = 80600
MEDIAN_MONTHLY_HOUSEHOLD_INCOME_2023 = MEDIAN_HOUSEHOLD_INCOME_2023 / 12

# Function to generate income around the median
def generate_income():
    log_mean = np.log(MEDIAN_HOUSEHOLD_INCOME_2023)
    income = np.random.lognormal(mean=log_mean, sigma=0.6) # Adjust sigma for spread
    return int(round(income, -2))

# Lists to store client data
client_ids = [f"client_{i+1:04d}" for i in range(num_clients)]
ages = np.random.randint(18, 65, num_clients)
genders = np.random.choice(['Male', 'Female', 'Other'], num_clients, p=[0.49, 0.49, 0.02])
locations = [fake.city() + ", " + fake.state_abbr() for _ in range(num_clients)]

# Income Data (standardized to monthly)
income_frequencies = ['Monthly', 'Annually', 'Bi-Weekly']
income_frequency = np.random.choice(income_frequencies, num_clients, p=[0.7, 0.2, 0.1])
incomes = []
monthly_incomes = []
for freq in income_frequency:
    base_annual_income = generate_income() # Generate roughly annual income
    incomes.append(base_annual_income)
    if freq == 'Annually':
        monthly_incomes.append(int(round(base_annual_income / 12, -2)))
    elif freq == 'Bi-Weekly':
        monthly_incomes.append(int(round(base_annual_income * 26 / 12, -2)))
    else:  # Monthly
        monthly_incomes.append(int(round(base_annual_income / 1, -2)))

# Profession Data
professions = [
    'Software Engineer', 'Data Scientist', 'Financial Analyst', 'Registered Nurse',
    'Teacher', 'Accountant', 'Project Manager', 'Marketing Specialist',
    'Sales Manager', 'Business Analyst', 'Electrician', 'Plumber', 'Lawyer',
    'Doctor', 'Pharmacist', 'Truck Driver', 'Customer Service Representative',
    'Administrative Assistant', 'Retail Manager', 'Chef', 'Mechanic'
]
profession = np.random.choice(professions, num_clients)

# Loan Data (Corrected)
loan_types = ['Mortgage', 'Auto Loan', 'Personal Loan', 'Credit Card Debt', None]
has_loan = np.random.choice([True, False], num_clients, p=[0.4, 0.6])

loan_data = []
for i in range(num_clients):  # Iterate by index to access corresponding income
    if has_loan[i]:
        loan_type = np.random.choice(loan_types[:-1])
        principal_amount = np.random.uniform(5000, monthly_incomes[i] * 3 * 12, 1)[0] if loan_type != 'Credit Card Debt' else np.random.uniform(500, monthly_incomes[i] * 0.5 * 12, 1)[0]
        interest_rate = np.random.uniform(0.03, 0.15, 1)[0]
        loan_term_months = np.random.randint(12, 360, 1)[0] if loan_type != 'Credit Card Debt' else None
        if loan_type in ['Mortgage', 'Auto Loan', 'Personal Loan'] and loan_term_months is not None and interest_rate > 0:
            monthly_interest_rate = interest_rate / 12
            emi = (principal_amount * monthly_interest_rate * (1 + monthly_interest_rate)**loan_term_months) / ((1 + monthly_interest_rate)**loan_term_months - 1)
            emi = round(emi, 2)
        else:
            emi = None
        loan_data.append({
            'loan_type': loan_type,
            'principal_amount': round(principal_amount, 2),
            'interest_rate': round(interest_rate, 4),
            'loan_term_months': loan_term_months,
            'emi': emi
        })
    else:
        loan_data.append({
            'loan_type': None,
            'principal_amount': None,
            'interest_rate': None,
            'loan_term_months': None,
            'emi': None
        })

# Spending Pattern (adjusting based on monthly income and standardizing to monthly)
spending_categories = {
    'Housing': (0.25, 0.40),
    'Food': (0.10, 0.20),
    'Transportation': (0.05, 0.15),
    'Utilities': (0.03, 0.08),
    'Healthcare': (0.02, 0.10),
    'Debt Payments': (0.05, 0.20),
    'Entertainment': (0.02, 0.10),
    'Savings': (0.05, 0.35), # Increased max savings
    'Miscellaneous': (0.03, 0.15)
}

monthly_spending_patterns = []
for income in monthly_incomes:
    pattern = {}
    remaining_percentage = 1.0
    savings_percentage = np.random.uniform(0.05, min(0.35, income / (MEDIAN_MONTHLY_HOUSEHOLD_INCOME_2023 * 2))) # Savings increase with income (cap at 35%)
    pattern['Savings'] = round(income * savings_percentage, 2)
    remaining_percentage -= savings_percentage
    for category, (min_p, max_p) in spending_categories.items():
        if category == 'Savings':
            continue
        if category == 'Miscellaneous':
            percentage = remaining_percentage
        else:
            base_percentage = np.random.uniform(min_p, max_p)
            adjustment_factor = 0.9 + np.random.rand() * 0.2
            percentage = min(remaining_percentage, base_percentage * adjustment_factor)
            remaining_percentage -= percentage
        pattern[category] = round(income * percentage, 2)
    monthly_spending_patterns.append(pattern)

financial_goals_options = [
    'Retirement',
    'Home Purchase',
    'Education Funding (Child/Self)',
    'Debt Repayment',
    'Early Financial Freedom/FIRE',
    'Healthcare Savings',
    'Travel',
    'Investment Growth',
    'Emergency Fund Building',
    'Other'
]
financial_goal_probabilities = [
    0.25,
    0.15,
    0.12,
    0.10,
    0.08,
    0.07,
    0.08,
    0.08,
    0.05,
    0.02
]
financial_goals = np.random.choice(
    financial_goals_options,
    num_clients,
    p=financial_goal_probabilities
)

# Create a Pandas DataFrame
client_data = pd.DataFrame({
    'client_id': client_ids,
    'age': ages,
    'gender': genders,
    'location': locations,
    'income': incomes,
    'income_frequency': income_frequency,
    'monthly_income': monthly_incomes,
    'profession': profession,
    'financial_goal': financial_goals,
    'loan_type': [loan['loan_type'] for loan in loan_data],
    'principal_amount': [loan['principal_amount'] for loan in loan_data],
    'interest_rate': [loan['interest_rate'] for loan in loan_data],
    'loan_term_months': [loan['loan_term_months'] for loan in loan_data],
    'emi': [loan['emi'] for loan in loan_data]
})

# Add spending pattern columns (now monthly)
spending_df = pd.DataFrame(monthly_spending_patterns)
client_data = pd.concat([client_data, spending_df], axis=1)

print(client_data.head())
print(f"\nGenerated {len(client_data)} client data points with income and spending standardized to monthly.")
# Out:
#      client_id  age  gender         location  income income_frequency  \
# 0  client_0001   50    Male    Bellburgh, HI   40400          Monthly
# 1  client_0002   40  Female    Smithport, CO  167700         Annually
# 2  client_0003   46    Male  East Robert, DC   81700          Monthly
# 3  client_0004   47    Male   Port Jesse, WA   52700          Monthly
# 4  client_0005   26  Female    Greenbury, FM  135400          Monthly
#
#    monthly_income                       profession           financial_goal  \
# 0           40400                   Data Scientist           Debt Repayment
# 1           14000  Customer Service Representative               Retirement
# 2           81700                      Electrician               Retirement
# 3           52700                          Plumber  Emergency Fund Building
# 4          135400                          Teacher                   Travel
#
#   loan_type  ...       emi   Savings   Housing      Food  Transportation  \
# 0      None  ...       NaN  10139.02  11259.92   4039.07         4663.94
# 1      None  ...       NaN   2565.23   4430.57   2046.58         1388.33
# 2      None  ...       NaN  14468.19  21234.73   9077.07         8373.36
# 3  Mortgage  ...  24880.37   4876.84  15141.36  10001.11         3068.39
# 4      None  ...       NaN  42531.74  52304.83  23611.04        11216.83
#
#    Utilities  Healthcare  Debt Payments  Entertainment  Miscellaneous
# 0    1445.54     1771.45        6799.47         281.58           0.00
# 1     864.55     1363.58        1341.17           0.00           0.00
# 2    4547.36     6153.57        5483.86        4138.90        8222.97
# 3    4064.09     2517.98        5795.14        2770.24        4464.86
# 4    5735.56        0.00           0.00           0.00           0.00
#
# [5 rows x 23 columns]
#
# Generated 5000 client data points with income and spending standardized to monthly.

# %%
client_data
# Out:
#         client_id  age  gender                location  income  \
# 0     client_0001   27    Male  Port Brittneymouth, CO   31500
# 1     client_0002   31    Male     Christopherland, MI  118300
# 2     client_0003   56  Female        Gardnermouth, VA   62600
# 3     client_0004   45    Male  South Rebeccamouth, PA   98000
# 4     client_0005   19  Female      Lake Angelaton, MA  130800
# ...           ...  ...     ...                     ...     ...
# 4995  client_4996   50  Female         Schultzberg, NV  125500
# 4996  client_4997   32  Female         Lake Joseph, NY  111400
# 4997  client_4998   49    Male           Frankfort, PW   31000
# 4998  client_4999   22  Female           Patelside, DC  122200
# 4999  client_5000   30    Male          Gomezshire, DE   53600
#
#      income_frequency  monthly_income                  financial_goal  \
# 0             Monthly           31500  Education Funding (Child/Self)
# 1             Monthly          118300                      Retirement
# 2            Annually            5200                      Retirement
# 3           Bi-Weekly          212300                   Home Purchase
# 4            Annually           10900                   Home Purchase
# ...               ...             ...                             ...
# 4995          Monthly          125500                          Travel
# 4996         Annually            9300  Education Funding (Child/Self)
# 4997          Monthly           31000               Investment Growth
# 4998          Monthly          122200                           Other
# 4999          Monthly           53600    Early Financial Freedom/FIRE
#
#              loan_type  principal_amount  ...      emi   Savings   Housing  \
# 0                 None               NaN  ...      NaN   2734.97  12006.39
# 1     Credit Card Debt         545036.04  ...      NaN  24223.06  43920.75
# 2     Credit Card Debt          15409.96  ...      NaN   1704.19   2059.13
# 3                 None               NaN  ...      NaN  63893.30  62743.01
# 4            Auto Loan         344761.34  ...  2641.72    810.68   3548.54
# ...                ...               ...  ...      ...       ...       ...
# 4995              None               NaN  ...      NaN  31747.97  53881.70
# 4996              None               NaN  ...      NaN   2533.25   2645.18
# 4997              None               NaN  ...      NaN   6222.09  12411.17
# 4998              None               NaN  ...      NaN  35144.53  35658.63
# 4999              None               NaN  ...      NaN   9818.12  20608.77
#
#           Food  Transportation  Utilities  Healthcare  Debt Payments  \
# 0      5027.94         3078.95    1376.45     3209.75        4065.56
# 1     17726.06        10544.29    4485.76     8440.82        6380.91
# 2       685.66          383.63     166.51      200.88           0.00
# 3     28821.27        32625.32   11355.89    12861.21           0.00
# 4      1010.99          691.38     885.70      426.95        1780.21
# ...        ...             ...        ...         ...            ...
# 4995  12704.83         9270.87    9439.34     8455.28           0.00
# 4996   1442.28          691.07     664.74      420.50         902.99
# 4997   6195.73         2661.02    1405.82      778.67        1325.49
# 4998  21852.21        13444.99    8878.07     7221.58           0.00
# 4999   8966.79         3562.83    3531.36     2933.31        4178.80
#
#       Entertainment  Miscellaneous
# 0              0.00           0.00
# 1           2578.36           0.00
# 2              0.00           0.00
# 3              0.00           0.00
# 4           1069.47         676.07
# ...             ...            ...
# 4995           0.00           0.00
# 4996           0.00           0.00
# 4997           0.00           0.00
# 4998           0.00           0.00
# 4999           0.00           0.00
#
# [5000 rows x 22 columns]

# %%
import pandas as pd

# Assuming you have the client_data DataFrame

def create_peer_groups(client_data: pd.DataFrame, income_bins=4, age_bins=3):
    """
    Creates peer group definitions based on monthly income, age, state, financial goals, and profession.

    Args:
        client_data (pd.DataFrame): DataFrame containing client data.
        income_bins (int): The number of income bins (applied to monthly income).
        age_bins (int): The number of age bins.

    Returns:
        tuple: A tuple containing:
            - pd.DataFrame: DataFrame with added 'peer_group_id' to client data.
            - pd.DataFrame: DataFrame defining peer group IDs and their descriptions.
    """
    income_cut = pd.cut(client_data['monthly_income'], bins=income_bins, labels=False, retbins=True)
    client_data['income_bin'] = income_cut[0]
    income_bin_edges = income_cut[1]

    age_cut = pd.cut(client_data['age'], bins=age_bins, labels=False, retbins=True)
    client_data['age_bin'] = age_cut[0]
    age_bin_edges = age_cut[1]

    unique_states = client_data['location'].str[-2:].unique()
    unique_goals = client_data['financial_goal'].unique()
    unique_professions = client_data['profession'].unique()  # Get unique professions

    peer_groups = []
    client_data['peer_group_id'] = ''
    group_counter = 1

    for i in range(income_bins):
        for j in range(age_bins):
            for state in unique_states:
                for goal in unique_goals:
                    for prof in unique_professions: # Iterate through professions
                        group_id = f"PG_{group_counter:03d}"
                        income_desc = f"Monthly Income: ${income_bin_edges[i]:,.0f} - ${income_bin_edges[i+1]:,.0f}"
                        age_desc = f"Age: {int(age_bin_edges[j])} - {int(age_bin_edges[j+1])}"
                        location_desc = f"State: {state}"
                        goal_desc = f"Goal: {goal}"
                        profession_desc = f"Profession: {prof}"  # Add profession to description
                        description = f"{income_desc}, {age_desc}, {location_desc}, {goal_desc}, {profession_desc}" # Include in combined description

                        peer_groups.append({'peer_group_id': group_id, 'description': description})

                        condition = (client_data['income_bin'] == i) & \
                                    (client_data['age_bin'] == j) & \
                                    (client_data['location'].str[-2:] == state) & \
                                    (client_data['financial_goal'] == goal) & \
                                    (client_data['profession'] == prof)  # Add profession to the condition

                        client_data.loc[condition, 'peer_group_id'] = group_id
                        group_counter += 1

    peer_group_df = pd.DataFrame(peer_groups)
    client_data = client_data.drop(columns=['income_bin', 'age_bin'])
    client_data['peer_group_id'] = client_data['peer_group_id'].replace('', None)

    return client_data, peer_group_df

# Generate sophisticated peer groups
client_data_with_peers, peer_group_definitions = create_sophisticated_peer_groups(client_data.copy(), income_bins=4, age_bins=3)

# Display the first few rows of client data with peer group IDs
print("Client Data with Peer Group IDs (including profession):")
print(client_data_with_peers[['client_id', 'age', 'monthly_income', 'location', 'profession', 'financial_goal', 'peer_group_id']].head())

# Display a sample of the peer group definitions
print("\nSample Peer Group Definitions (including profession):")
print(peer_group_definitions.head())

# Display the distribution of clients across the generated peer groups
print("\nDistribution of clients across peer groups (top counts, including profession):")
print(client_data_with_peers['peer_group_id'].value_counts().head())

print(f"\nTotal number of defined peer groups: {len(peer_group_definitions)}")
print(f"Number of clients assigned to a peer group: {client_data_with_peers['peer_group_id'].count()}")
print(f"Number of clients without a peer group: {client_data_with_peers['peer_group_id'].isnull().sum()}")
# Out:
# Client Data with Peer Group IDs (including profession):
#      client_id  age  monthly_income         location  \
# 0  client_0001   50           40400    Bellburgh, HI
# 1  client_0002   40           14000    Smithport, CO
# 2  client_0003   46           81700  East Robert, DC
# 3  client_0004   47           52700   Port Jesse, WA
# 4  client_0005   26          135400    Greenbury, FM
#
#                         profession           financial_goal peer_group_id
# 0                   Data Scientist           Debt Repayment       PG_1181
# 1  Customer Service Representative               Retirement       PG_2372
# 2                      Electrician               Retirement        PG_612
# 3                          Plumber  Emergency Fund Building        PG_623
# 4                          Teacher                   Travel        PG_044
#
# Sample Peer Group Definitions (including profession):
#   peer_group_id  \
# 0        PG_001
# 1        PG_002
# 2        PG_003
# 3        PG_004
# 4        PG_005
#
#                                                                          description
# 0           Income: $8,759 - $144,500, Age: 17 - 33, State: HI, Goal: Debt Repayment
# 1               Income: $8,759 - $144,500, Age: 17 - 33, State: HI, Goal: Retirement
# 2  Income: $8,759 - $144,500, Age: 17 - 33, State: HI, Goal: Emergency Fund Building
# 3                   Income: $8,759 - $144,500, Age: 17 - 33, State: HI, Goal: Travel
# 4            Income: $8,759 - $144,500, Age: 17 - 33, State: HI, Goal: Home Purchase
#
# Distribution of clients across peer groups (top counts, including profession):
# peer_group_id
# PG_622     11
# PG_1242    11
# PG_472     11
# PG_342     11
# PG_1655    10
# Name: count, dtype: int64
#
# Total number of defined peer groups: 7080
# Number of clients assigned to a peer group: 5000
# Number of clients without a peer group: 0

# %%
client_data_with_peers.to_csv('client_data_with_peers.csv', index=False)

# %%
peer_group_definitions.to_csv('peer_group_definitions.csv', index=False)

# %%
client_data_with_peers['peer_group_id'].value_counts()
# Out:
# peer_group_id
# PG_622     11
# PG_1242    11
# PG_472     11
# PG_342     11
# PG_1655    10
#            ..
# PG_1867     1
# PG_2591     1
# PG_3421     1
# PG_475      1
# PG_844      1
# Name: count, Length: 2136, dtype: int64

# %%
import pandas as pd
from langchain.graphs import Neo4jGraph
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings  # Or any other embedding model
from langchain.schema import Document
import os
from dotenv import load_dotenv

# Assuming you have client_data_with_peers and peer_group_definitions DataFrames

# 1. Knowledge Graph Setup (Neo4j)
# --------------------------------
#    * Ensure you have a Neo4j instance running and the Neo4j Python driver installed.
#    * Set up environment variables for your Neo4j connection:
#        * NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD

NEO4J_URI = os.environ["NEO4J_URI"]
NEO4J_USER = os.environ["NEO4J_USER"]
NEO4J_PASSWORD = os.environ["NEO4J_PASSWORD"]

graph = Neo4jGraph(url=NEO4J_URI, username=NEO4J_USER, password=NEO4J_PASSWORD)

def create_kg_nodes(client_data: pd.DataFrame):
    """
    Creates nodes in the knowledge graph for clients and peer groups.
    """
    for _, row in client_data.iterrows():
        client_id = row['client_id']
        age = row['age']
        gender = row['gender']
        location = row['location']
        income = row['income']
        income_frequency = row['income_frequency']
        profession = row['profession']
        financial_goal = row['financial_goal']

        #  Create Client node
        graph.query(f"""
            CREATE (c:Client {{
                client_id: '{client_id}',
                age: {age},
                gender: '{gender}',
                location: '{location}',
                income: {income},
                income_frequency: '{income_frequency}',
                profession: '{profession}',
                financial_goal: '{financial_goal}'
            }})
        """)

        # if row['peer_group_id']:
        #     peer_group_id = row['peer_group_id']
        #     # Link Client to PeerGroup
        #     graph.query(f"""
        #         MATCH (c:Client {{client_id: '{client_id}'}}),
        #               (pg:PeerGroup {{peer_group_id: '{peer_group_id}'}})
        #         CREATE (c)-[:BELONGS_TO]->(pg)
        #     """)

def create_kg_peer_groups(peer_group_definitions: pd.DataFrame):
    """
    Creates PeerGroup nodes in the knowledge graph.
    """
    for _, row in peer_group_definitions.iterrows():
        peer_group_id = row['peer_group_id']
        description = row['description']
        graph.query(f"""
            CREATE (pg:PeerGroup {{
                peer_group_id: '{peer_group_id}',
                description: '{description}'
            }})
        """)

# Create KG nodes
create_kg_nodes(client_data_with_peers)
create_kg_peer_groups(peer_group_definitions)

# %%
import pandas as pd
client_data_with_peers = pd.read_csv('client_data_with_peers.csv')
client_data_with_peers.columns
# Out:
# Index(['client_id', 'age', 'gender', 'location', 'income', 'income_frequency',
#        'monthly_income', 'profession', 'financial_goal', 'loan_type',
#        'principal_amount', 'interest_rate', 'loan_term_months', 'emi',
#        'Savings', 'Housing', 'Food', 'Transportation', 'Utilities',
#        'Healthcare', 'Debt Payments', 'Entertainment', 'Miscellaneous',
#        'peer_group_id'],
#       dtype='object')

# %%
from langchain_neo4j import Neo4jGraph
import os

# 1.  Connect to Neo4j
# ----------------------
NEO4J_URI = os.environ["NEO4J_URI"]
NEO4J_USER = os.environ["NEO4J_USER"]
NEO4J_PASSWORD = os.environ["NEO4J_PASSWORD"]

graph = Neo4jGraph(url=NEO4J_URI, username=NEO4J_USER, password=NEO4J_PASSWORD)

# 2. Add Unique Constraints
# --------------------------
def add_unique_constraints():
    """
    Adds unique constraints to the Client and PeerGroup nodes.
    """
    try:
        graph.query("CREATE CONSTRAINT IF NOT EXISTS FOR (c:Client) REQUIRE c.client_id IS UNIQUE")
        print("Unique constraint added for Client: client_id")
    except Exception as e:
        print(f"Error adding unique constraint for Client: {e}")

    try:
        graph.query("CREATE CONSTRAINT IF NOT EXISTS FOR (pg:PeerGroup) REQUIRE pg.peer_group_id IS UNIQUE")
        print("Unique constraint added for PeerGroup: peer_group_id")
    except Exception as e:
        print(f"Error adding unique constraint for PeerGroup: {e}")

# 3. Establish Relationships (BELONGS_TO)
# -----------------------------------------
def create_relationships(client_data: pd.DataFrame):
    """
    Establishes BELONGS_TO relationships between Client and PeerGroup nodes
    based on the peer_group_id in the client_data DataFrame.

    Args:
        client_data (pd.DataFrame): DataFrame containing client data with 'client_id' and 'peer_group_id'.
    """
    for _, row in client_data.iterrows():
        client_id = row['client_id']
        peer_group_id = row['peer_group_id']

        if peer_group_id:  # Only create relationships if peer_group_id is not None/empty
            try:
                graph.query(f"""
                    MATCH (c:Client {{client_id: '{client_id}'}}),
                          (pg:PeerGroup {{peer_group_id: '{peer_group_id}'}})
                    CREATE (c)-[:BELONGS_TO]->(pg)
                """)
                print(f"Relationship created: Client '{client_id}' BELONGS_TO PeerGroup '{peer_group_id}'")
            except Exception as e:
                print(f"Error creating relationship for Client '{client_id}': {e}")
        else:
            print(f"Client '{client_id}' not assigned to any peer group.")

# Assuming you have the client_data DataFrame available
# Add constraints
add_unique_constraints()

# Create relationships (assuming client_data_with_peers is available)
create_relationships(client_data_with_peers)
# Out:
# Unique constraint added for Client: client_id
# Unique constraint added for PeerGroup: peer_group_id
# Relationship created: Client 'client_0001' BELONGS_TO PeerGroup 'PG_1181'
# Relationship created: Client 'client_0002' BELONGS_TO PeerGroup 'PG_2372'
# Relationship created: Client 'client_0003' BELONGS_TO PeerGroup 'PG_612'
# Relationship created: Client 'client_0004' BELONGS_TO PeerGroup 'PG_623'
# Relationship created: Client 'client_0005' BELONGS_TO PeerGroup 'PG_044'
# Relationship created: Client 'client_0006' BELONGS_TO PeerGroup 'PG_1235'
# Relationship created: Client 'client_0007' BELONGS_TO PeerGroup 'PG_651'
# Relationship created: Client 'client_0008' BELONGS_TO PeerGroup 'PG_1256'
# Relationship created: Client 'client_0009' BELONGS_TO PeerGroup 'PG_083'
# Relationship created: Client 'client_0010' BELONGS_TO PeerGroup 'PG_3042'
# Relationship created: Client 'client_0011' BELONGS_TO PeerGroup 'PG_1245'
# Relationship created: Client 'client_0012' BELONGS_TO PeerGroup 'PG_1281'
# Relationship created: Client 'client_0013' BELONGS_TO PeerGroup 'PG_2475'
# Relationship created: Client 'client_0014' BELONGS_TO PeerGroup 'PG_127'
# Relationship created: Client 'client_0015' BELONGS_TO PeerGroup 'PG_112'
# Relationship created: Client 'client_0016' BELONGS_TO PeerGroup 'PG_135'
# Relationship created: Client 'client_0017' BELONGS_TO PeerGroup 'PG_738'
# Relationship created: Client 'client_0018' BELONGS_TO PeerGroup 'PG_3104'
# Relationship created: Client 'client_0019' BELONGS_TO PeerGroup 'PG_1349'
# Relationship created: Client 'client_0020' BELONGS_TO PeerGroup 'PG_1356'
# Relationship created: Client 'client_0021' BELONGS_TO PeerGroup 'PG_778'
# Relationship created: Client 'client_0022' BELONGS_TO PeerGroup 'PG_675'
# Relationship created: Client 'client_0023' BELONGS_TO PeerGroup 'PG_1372'
# Relationship created: Client 'client_0024' BELONGS_TO PeerGroup 'PG_208'
# Relationship created: Client 'client_0025' BELONGS_TO PeerGroup 'PG_1984'
# Relationship created: Client 'client_0026' BELONGS_TO PeerGroup 'PG_1202'
# Relationship created: Client 'client_0027' BELONGS_TO PeerGroup 'PG_775'
# Relationship created: Client 'client_0028' BELONGS_TO PeerGroup 'PG_812'
# Relationship created: Client 'client_0029' BELONGS_TO PeerGroup 'PG_1286'
# Relationship created: Client 'client_0030' BELONGS_TO PeerGroup 'PG_1365'
# Relationship created: Client 'client_0031' BELONGS_TO PeerGroup 'PG_181'
# Relationship created: Client 'client_0032' BELONGS_TO PeerGroup 'PG_236'
# Relationship created: Client 'client_0033' BELONGS_TO PeerGroup 'PG_062'
# Relationship created: Client 'client_0034' BELONGS_TO PeerGroup 'PG_023'
# Relationship created: Client 'client_0035' BELONGS_TO PeerGroup 'PG_249'
# Relationship created: Client 'client_0036' BELONGS_TO PeerGroup 'PG_3203'
# Relationship created: Client 'client_0037' BELONGS_TO PeerGroup 'PG_853'
# Relationship created: Client 'client_0038' BELONGS_TO PeerGroup 'PG_275'
# Relationship created: Client 'client_0039' BELONGS_TO PeerGroup 'PG_225'
# Relationship created: Client 'client_0040' BELONGS_TO PeerGroup 'PG_874'
# Relationship created: Client 'client_0041' BELONGS_TO PeerGroup 'PG_672'
# Relationship created: Client 'client_0042' BELONGS_TO PeerGroup 'PG_3094'
# Relationship created: Client 'client_0043' BELONGS_TO PeerGroup 'PG_2065'
# Relationship created: Client 'client_0044' BELONGS_TO PeerGroup 'PG_2661'
# Relationship created: Client 'client_0045' BELONGS_TO PeerGroup 'PG_2452'
# Relationship created: Client 'client_0046' BELONGS_TO PeerGroup 'PG_078'
# Relationship created: Client 'client_0047' BELONGS_TO PeerGroup 'PG_317'
# Relationship created: Client 'client_0048' BELONGS_TO PeerGroup 'PG_715'
# Relationship created: Client 'client_0049' BELONGS_TO PeerGroup 'PG_1502'
# Relationship created: Client 'client_0050' BELONGS_TO PeerGroup 'PG_1312'
# Relationship created: Client 'client_0051' BELONGS_TO PeerGroup 'PG_1514'
# Relationship created: Client 'client_0052' BELONGS_TO PeerGroup 'PG_1494'
# Relationship created: Client 'client_0053' BELONGS_TO PeerGroup 'PG_1522'
# Relationship created: Client 'client_0054' BELONGS_TO PeerGroup 'PG_6255'
# Relationship created: Client 'client_0055' BELONGS_TO PeerGroup 'PG_2436'
# Relationship created: Client 'client_0056' BELONGS_TO PeerGroup 'PG_1542'
# Relationship created: Client 'client_0057' BELONGS_TO PeerGroup 'PG_962'
# Relationship created: Client 'client_0058' BELONGS_TO PeerGroup 'PG_913'
# Relationship created: Client 'client_0059' BELONGS_TO PeerGroup 'PG_872'
# Relationship created: Client 'client_0060' BELONGS_TO PeerGroup 'PG_1465'
# Relationship created: Client 'client_0061' BELONGS_TO PeerGroup 'PG_375'
# Relationship created: Client 'client_0062' BELONGS_TO PeerGroup 'PG_6132'
# Relationship created: Client 'client_0063' BELONGS_TO PeerGroup 'PG_972'
# Relationship created: Client 'client_0064' BELONGS_TO PeerGroup 'PG_594'
# Relationship created: Client 'client_0065' BELONGS_TO PeerGroup 'PG_2091'
# Relationship created: Client 'client_0066' BELONGS_TO PeerGroup 'PG_1319'
# Relationship created: Client 'client_0067' BELONGS_TO PeerGroup 'PG_394'
# Relationship created: Client 'client_0068' BELONGS_TO PeerGroup 'PG_341'
# Relationship created: Client 'client_0069' BELONGS_TO PeerGroup 'PG_1241'
# Relationship created: Client 'client_0070' BELONGS_TO PeerGroup 'PG_706'
# Relationship created: Client 'client_0071' BELONGS_TO PeerGroup 'PG_1909'
# Relationship created: Client 'client_0072' BELONGS_TO PeerGroup 'PG_1551'
# Relationship created: Client 'client_0073' BELONGS_TO PeerGroup 'PG_018'
# Relationship created: Client 'client_0074' BELONGS_TO PeerGroup 'PG_404'
# Relationship created: Client 'client_0075' BELONGS_TO PeerGroup 'PG_1001'
# Relationship created: Client 'client_0076' BELONGS_TO PeerGroup 'PG_426'
# Relationship created: Client 'client_0077' BELONGS_TO PeerGroup 'PG_252'
# Relationship created: Client 'client_0078' BELONGS_TO PeerGroup 'PG_3382'
# Relationship created: Client 'client_0079' BELONGS_TO PeerGroup 'PG_371'
# Relationship created: Client 'client_0080' BELONGS_TO PeerGroup 'PG_2535'
# Relationship created: Client 'client_0081' BELONGS_TO PeerGroup 'PG_1034'
# Relationship created: Client 'client_0082' BELONGS_TO PeerGroup 'PG_207'
# Relationship created: Client 'client_0083' BELONGS_TO PeerGroup 'PG_1635'
# Relationship created: Client 'client_0084' BELONGS_TO PeerGroup 'PG_1052'
# Relationship created: Client 'client_0085' BELONGS_TO PeerGroup 'PG_282'
# Relationship created: Client 'client_0086' BELONGS_TO PeerGroup 'PG_245'
# Relationship created: Client 'client_0087' BELONGS_TO PeerGroup 'PG_4328'
# Relationship created: Client 'client_0088' BELONGS_TO PeerGroup 'PG_1352'
# Relationship created: Client 'client_0089' BELONGS_TO PeerGroup 'PG_612'
# Relationship created: Client 'client_0090' BELONGS_TO PeerGroup 'PG_1775'
# Relationship created: Client 'client_0091' BELONGS_TO PeerGroup 'PG_919'
# Relationship created: Client 'client_0092' BELONGS_TO PeerGroup 'PG_105'
# Relationship created: Client 'client_0093' BELONGS_TO PeerGroup 'PG_1257'
# Relationship created: Client 'client_0094' BELONGS_TO PeerGroup 'PG_404'
# Relationship created: Client 'client_0095' BELONGS_TO PeerGroup 'PG_1358'
# Relationship created: Client 'client_0096' BELONGS_TO PeerGroup 'PG_321'
# Relationship created: Client 'client_0097' BELONGS_TO PeerGroup 'PG_1424'
# Relationship created: Client 'client_0098' BELONGS_TO PeerGroup 'PG_1061'
# Relationship created: Client 'client_0099' BELONGS_TO PeerGroup 'PG_397'
# Relationship created: Client 'client_0100' BELONGS_TO PeerGroup 'PG_167'
# Relationship created: Client 'client_0101' BELONGS_TO PeerGroup 'PG_1662'
# Relationship created: Client 'client_0102' BELONGS_TO PeerGroup 'PG_153'
# Relationship created: Client 'client_0103' BELONGS_TO PeerGroup 'PG_231'
# Relationship created: Client 'client_0104' BELONGS_TO PeerGroup 'PG_2037'
# Relationship created: Client 'client_0105' BELONGS_TO PeerGroup 'PG_3008'
# Relationship created: Client 'client_0106' BELONGS_TO PeerGroup 'PG_1677'
# Relationship created: Client 'client_0107' BELONGS_TO PeerGroup 'PG_2175'
# Relationship created: Client 'client_0108' BELONGS_TO PeerGroup 'PG_601'
# Relationship created: Client 'client_0109' BELONGS_TO PeerGroup 'PG_416'
# Relationship created: Client 'client_0110' BELONGS_TO PeerGroup 'PG_1648'
# Relationship created: Client 'client_0111' BELONGS_TO PeerGroup 'PG_044'
# Relationship created: Client 'client_0112' BELONGS_TO PeerGroup 'PG_1582'
# Relationship created: Client 'client_0113' BELONGS_TO PeerGroup 'PG_4771'
# Relationship created: Client 'client_0114' BELONGS_TO PeerGroup 'PG_096'
# Relationship created: Client 'client_0115' BELONGS_TO PeerGroup 'PG_509'
# Relationship created: Client 'client_0116' BELONGS_TO PeerGroup 'PG_1682'
# Relationship created: Client 'client_0117' BELONGS_TO PeerGroup 'PG_592'
# Relationship created: Client 'client_0118' BELONGS_TO PeerGroup 'PG_511'
# Relationship created: Client 'client_0119' BELONGS_TO PeerGroup 'PG_1325'
# Relationship created: Client 'client_0120' BELONGS_TO PeerGroup 'PG_1538'
# Relationship created: Client 'client_0121' BELONGS_TO PeerGroup 'PG_502'
# Relationship created: Client 'client_0122' BELONGS_TO PeerGroup 'PG_644'
# Relationship created: Client 'client_0123' BELONGS_TO PeerGroup 'PG_1359'
# Relationship created: Client 'client_0124' BELONGS_TO PeerGroup 'PG_322'
# Relationship created: Client 'client_0125' BELONGS_TO PeerGroup 'PG_1021'
# Relationship created: Client 'client_0126' BELONGS_TO PeerGroup 'PG_521'
# Relationship created: Client 'client_0127' BELONGS_TO PeerGroup 'PG_1441'
# Relationship created: Client 'client_0128' BELONGS_TO PeerGroup 'PG_645'
# Relationship created: Client 'client_0129' BELONGS_TO PeerGroup 'PG_1323'
# Relationship created: Client 'client_0130' BELONGS_TO PeerGroup 'PG_917'
# Relationship created: Client 'client_0131' BELONGS_TO PeerGroup 'PG_1563'
# Relationship created: Client 'client_0132' BELONGS_TO PeerGroup 'PG_266'
# Relationship created: Client 'client_0133' BELONGS_TO PeerGroup 'PG_540'
# Relationship created: Client 'client_0134' BELONGS_TO PeerGroup 'PG_205'
# Relationship created: Client 'client_0135' BELONGS_TO PeerGroup 'PG_1429'
# Relationship created: Client 'client_0136' BELONGS_TO PeerGroup 'PG_1207'
# Relationship created: Client 'client_0137' BELONGS_TO PeerGroup 'PG_324'
# Relationship created: Client 'client_0138' BELONGS_TO PeerGroup 'PG_088'
# Relationship created: Client 'client_0139' BELONGS_TO PeerGroup 'PG_042'
# Relationship created: Client 'client_0140' BELONGS_TO PeerGroup 'PG_1020'
# Relationship created: Client 'client_0141' BELONGS_TO PeerGroup 'PG_1218'
# Relationship created: Client 'client_0142' BELONGS_TO PeerGroup 'PG_151'
# Relationship created: Client 'client_0143' BELONGS_TO PeerGroup 'PG_1642'
# Relationship created: Client 'client_0144' BELONGS_TO PeerGroup 'PG_1399'
# Relationship created: Client 'client_0145' BELONGS_TO PeerGroup 'PG_1707'
# Relationship created: Client 'client_0146' BELONGS_TO PeerGroup 'PG_2389'
# Relationship created: Client 'client_0147' BELONGS_TO PeerGroup 'PG_302'
# Relationship created: Client 'client_0148' BELONGS_TO PeerGroup 'PG_2316'
# Relationship created: Client 'client_0149' BELONGS_TO PeerGroup 'PG_006'
# Relationship created: Client 'client_0150' BELONGS_TO PeerGroup 'PG_1083'
# Relationship created: Client 'client_0151' BELONGS_TO PeerGroup 'PG_1705'
# Relationship created: Client 'client_0152' BELONGS_TO PeerGroup 'PG_093'
# Relationship created: Client 'client_0153' BELONGS_TO PeerGroup 'PG_608'
# Relationship created: Client 'client_0154' BELONGS_TO PeerGroup 'PG_1422'
# Relationship created: Client 'client_0155' BELONGS_TO PeerGroup 'PG_483'
# Relationship created: Client 'client_0156' BELONGS_TO PeerGroup 'PG_3505'
# Relationship created: Client 'client_0157' BELONGS_TO PeerGroup 'PG_252'
# Relationship created: Client 'client_0158' BELONGS_TO PeerGroup 'PG_362'
# Relationship created: Client 'client_0159' BELONGS_TO PeerGroup 'PG_1181'
# Relationship created: Client 'client_0160' BELONGS_TO PeerGroup 'PG_005'
# Relationship created: Client 'client_0161' BELONGS_TO PeerGroup 'PG_468'
# Relationship created: Client 'client_0162' BELONGS_TO PeerGroup 'PG_1417'
# Relationship created: Client 'client_0163' BELONGS_TO PeerGroup 'PG_750'
# Relationship created: Client 'client_0164' BELONGS_TO PeerGroup 'PG_204'
# Relationship created: Client 'client_0165' BELONGS_TO PeerGroup 'PG_1468'
# Relationship created: Client 'client_0166' BELONGS_TO PeerGroup 'PG_563'
# Relationship created: Client 'client_0167' BELONGS_TO PeerGroup 'PG_1818'
# Relationship created: Client 'client_0168' BELONGS_TO PeerGroup 'PG_1651'
# Relationship created: Client 'client_0169' BELONGS_TO PeerGroup 'PG_967'
# Relationship created: Client 'client_0170' BELONGS_TO PeerGroup 'PG_1546'
# Relationship created: Client 'client_0171' BELONGS_TO PeerGroup 'PG_188'
# Relationship created: Client 'client_0172' BELONGS_TO PeerGroup 'PG_2698'
# Relationship created: Client 'client_0173' BELONGS_TO PeerGroup 'PG_505'
# Relationship created: Client 'client_0174' BELONGS_TO PeerGroup 'PG_1607'
# Relationship created: Client 'client_0175' BELONGS_TO PeerGroup 'PG_2194'
# Relationship created: Client 'client_0176' BELONGS_TO PeerGroup 'PG_2517'
# Relationship created: Client 'client_0177' BELONGS_TO PeerGroup 'PG_114'
# Relationship created: Client 'client_0178' BELONGS_TO PeerGroup 'PG_1284'
# Relationship created: Client 'client_0179' BELONGS_TO PeerGroup 'PG_1920'
# Relationship created: Client 'client_0180' BELONGS_TO PeerGroup 'PG_3201'
# Relationship created: Client 'client_0181' BELONGS_TO PeerGroup 'PG_966'
# Relationship created: Client 'client_0182' BELONGS_TO PeerGroup 'PG_1315'
# Relationship created: Client 'client_0183' BELONGS_TO PeerGroup 'PG_1245'
# Relationship created: Client 'client_0184' BELONGS_TO PeerGroup 'PG_532'
# Relationship created: Client 'client_0185' BELONGS_TO PeerGroup 'PG_221'
# Relationship created: Client 'client_0186' BELONGS_TO PeerGroup 'PG_1786'
# Relationship created: Client 'client_0187' BELONGS_TO PeerGroup 'PG_1415'
# Relationship created: Client 'client_0188' BELONGS_TO PeerGroup 'PG_197'
# Relationship created: Client 'client_0189' BELONGS_TO PeerGroup 'PG_731'
# Relationship created: Client 'client_0190' BELONGS_TO PeerGroup 'PG_1517'
# Relationship created: Client 'client_0191' BELONGS_TO PeerGroup 'PG_871'
# Relationship created: Client 'client_0192' BELONGS_TO PeerGroup 'PG_039'
# Relationship created: Client 'client_0193' BELONGS_TO PeerGroup 'PG_1709'
# Relationship created: Client 'client_0194' BELONGS_TO PeerGroup 'PG_053'
# Relationship created: Client 'client_0195' BELONGS_TO PeerGroup 'PG_892'
# Relationship created: Client 'client_0196' BELONGS_TO PeerGroup 'PG_1360'
# Relationship created: Client 'client_0197' BELONGS_TO PeerGroup 'PG_1235'
# Relationship created: Client 'client_0198' BELONGS_TO PeerGroup 'PG_172'
# Relationship created: Client 'client_0199' BELONGS_TO PeerGroup 'PG_156'
# Relationship created: Client 'client_0200' BELONGS_TO PeerGroup 'PG_577'
# Relationship created: Client 'client_0201' BELONGS_TO PeerGroup 'PG_721'
# Relationship created: Client 'client_0202' BELONGS_TO PeerGroup 'PG_672'
# Relationship created: Client 'client_0203' BELONGS_TO PeerGroup 'PG_2154'
# Relationship created: Client 'client_0204' BELONGS_TO PeerGroup 'PG_1585'
# Relationship created: Client 'client_0205' BELONGS_TO PeerGroup 'PG_022'
# Relationship created: Client 'client_0206' BELONGS_TO PeerGroup 'PG_066'
# Relationship created: Client 'client_0207' BELONGS_TO PeerGroup 'PG_1491'
# Relationship created: Client 'client_0208' BELONGS_TO PeerGroup 'PG_1437'
# Relationship created: Client 'client_0209' BELONGS_TO PeerGroup 'PG_121'
# Relationship created: Client 'client_0210' BELONGS_TO PeerGroup 'PG_1456'
# Relationship created: Client 'client_0211' BELONGS_TO PeerGroup 'PG_1124'
# Relationship created: Client 'client_0212' BELONGS_TO PeerGroup 'PG_1574'
# Relationship created: Client 'client_0213' BELONGS_TO PeerGroup 'PG_1644'
# Relationship created: Client 'client_0214' BELONGS_TO PeerGroup 'PG_717'
# Relationship created: Client 'client_0215' BELONGS_TO PeerGroup 'PG_672'
# Relationship created: Client 'client_0216' BELONGS_TO PeerGroup 'PG_617'
# Relationship created: Client 'client_0217' BELONGS_TO PeerGroup 'PG_1745'
# Relationship created: Client 'client_0218' BELONGS_TO PeerGroup 'PG_854'
# Relationship created: Client 'client_0219' BELONGS_TO PeerGroup 'PG_529'
# Relationship created: Client 'client_0220' BELONGS_TO PeerGroup 'PG_1769'
# Relationship created: Client 'client_0221' BELONGS_TO PeerGroup 'PG_1601'
# Relationship created: Client 'client_0222' BELONGS_TO PeerGroup 'PG_1246'
# Relationship created: Client 'client_0223' BELONGS_TO PeerGroup 'PG_709'
# Relationship created: Client 'client_0224' BELONGS_TO PeerGroup 'PG_1266'
# Relationship created: Client 'client_0225' BELONGS_TO PeerGroup 'PG_676'
# Relationship created: Client 'client_0226' BELONGS_TO PeerGroup 'PG_1057'
# Relationship created: Client 'client_0227' BELONGS_TO PeerGroup 'PG_1387'
# Relationship created: Client 'client_0228' BELONGS_TO PeerGroup 'PG_157'
# Relationship created: Client 'client_0229' BELONGS_TO PeerGroup 'PG_1728'
# Relationship created: Client 'client_0230' BELONGS_TO PeerGroup 'PG_932'
# Relationship created: Client 'client_0231' BELONGS_TO PeerGroup 'PG_1135'
# Relationship created: Client 'client_0232' BELONGS_TO PeerGroup 'PG_022'
# Relationship created: Client 'client_0233' BELONGS_TO PeerGroup 'PG_2973'
# Relationship created: Client 'client_0234' BELONGS_TO PeerGroup 'PG_1119'
# Relationship created: Client 'client_0235' BELONGS_TO PeerGroup 'PG_287'
# Relationship created: Client 'client_0236' BELONGS_TO PeerGroup 'PG_155'
# Relationship created: Client 'client_0237' BELONGS_TO PeerGroup 'PG_1416'
# Relationship created: Client 'client_0238' BELONGS_TO PeerGroup 'PG_1009'
# Relationship created: Client 'client_0239' BELONGS_TO PeerGroup 'PG_2795'
# Relationship created: Client 'client_0240' BELONGS_TO PeerGroup 'PG_702'
# Relationship created: Client 'client_0241' BELONGS_TO PeerGroup 'PG_942'
# Relationship created: Client 'client_0242' BELONGS_TO PeerGroup 'PG_411'
# Relationship created: Client 'client_0243' BELONGS_TO PeerGroup 'PG_291'
# Relationship created: Client 'client_0244' BELONGS_TO PeerGroup 'PG_378'
# Relationship created: Client 'client_0245' BELONGS_TO PeerGroup 'PG_1272'
# Relationship created: Client 'client_0246' BELONGS_TO PeerGroup 'PG_1735'
# Relationship created: Client 'client_0247' BELONGS_TO PeerGroup 'PG_1729'
# Relationship created: Client 'client_0248' BELONGS_TO PeerGroup 'PG_1679'
# Relationship created: Client 'client_0249' BELONGS_TO PeerGroup 'PG_294'
# Relationship created: Client 'client_0250' BELONGS_TO PeerGroup 'PG_667'
# Relationship created: Client 'client_0251' BELONGS_TO PeerGroup 'PG_479'
# Relationship created: Client 'client_0252' BELONGS_TO PeerGroup 'PG_3142'
# Relationship created: Client 'client_0253' BELONGS_TO PeerGroup 'PG_1478'
# Relationship created: Client 'client_0254' BELONGS_TO PeerGroup 'PG_1514'
# Relationship created: Client 'client_0255' BELONGS_TO PeerGroup 'PG_546'
# Relationship created: Client 'client_0256' BELONGS_TO PeerGroup 'PG_837'
# Relationship created: Client 'client_0257' BELONGS_TO PeerGroup 'PG_367'
# Relationship created: Client 'client_0258' BELONGS_TO PeerGroup 'PG_939'
# Relationship created: Client 'client_0259' BELONGS_TO PeerGroup 'PG_1211'
# Relationship created: Client 'client_0260' BELONGS_TO PeerGroup 'PG_1525'
# Relationship created: Client 'client_0261' BELONGS_TO PeerGroup 'PG_251'
# Relationship created: Client 'client_0262' BELONGS_TO PeerGroup 'PG_1287'
# Relationship created: Client 'client_0263' BELONGS_TO PeerGroup 'PG_782'
# Relationship created: Client 'client_0264' BELONGS_TO PeerGroup 'PG_4828'
# Relationship created: Client 'client_0265' BELONGS_TO PeerGroup 'PG_2666'
# Relationship created: Client 'client_0266' BELONGS_TO PeerGroup 'PG_892'
# Relationship created: Client 'client_0267' BELONGS_TO PeerGroup 'PG_1380'
# Relationship created: Client 'client_0268' BELONGS_TO PeerGroup 'PG_482'
# Relationship created: Client 'client_0269' BELONGS_TO PeerGroup 'PG_367'
# Relationship created: Client 'client_0270' BELONGS_TO PeerGroup 'PG_891'
# Relationship created: Client 'client_0271' BELONGS_TO PeerGroup 'PG_2515'
# Relationship created: Client 'client_0272' BELONGS_TO PeerGroup 'PG_1172'
# Relationship created: Client 'client_0273' BELONGS_TO PeerGroup 'PG_535'
# Relationship created: Client 'client_0274' BELONGS_TO PeerGroup 'PG_811'
# Relationship created: Client 'client_0275' BELONGS_TO PeerGroup 'PG_308'
# Relationship created: Client 'client_0276' BELONGS_TO PeerGroup 'PG_2164'
# Relationship created: Client 'client_0277' BELONGS_TO PeerGroup 'PG_892'
# Relationship created: Client 'client_0278' BELONGS_TO PeerGroup 'PG_1563'
# Relationship created: Client 'client_0279' BELONGS_TO PeerGroup 'PG_508'
# Relationship created: Client 'client_0280' BELONGS_TO PeerGroup 'PG_1388'
# Relationship created: Client 'client_0281' BELONGS_TO PeerGroup 'PG_1354'
# Relationship created: Client 'client_0282' BELONGS_TO PeerGroup 'PG_392'
# Relationship created: Client 'client_0283' BELONGS_TO PeerGroup 'PG_1663'
# Relationship created: Client 'client_0284' BELONGS_TO PeerGroup 'PG_921'
# Relationship created: Client 'client_0285' BELONGS_TO PeerGroup 'PG_489'
# Relationship created: Client 'client_0286' BELONGS_TO PeerGroup 'PG_1562'
# Relationship created: Client 'client_0287' BELONGS_TO PeerGroup 'PG_1775'
# Relationship created: Client 'client_0288' BELONGS_TO PeerGroup 'PG_089'
# Relationship created: Client 'client_0289' BELONGS_TO PeerGroup 'PG_1753'
# Relationship created: Client 'client_0290' BELONGS_TO PeerGroup 'PG_312'
# Relationship created: Client 'client_0291' BELONGS_TO PeerGroup 'PG_302'
# Relationship created: Client 'client_0292' BELONGS_TO PeerGroup 'PG_435'
# Relationship created: Client 'client_0293' BELONGS_TO PeerGroup 'PG_1423'
# Relationship created: Client 'client_0294' BELONGS_TO PeerGroup 'PG_061'
# Relationship created: Client 'client_0295' BELONGS_TO PeerGroup 'PG_2347'
# Relationship created: Client 'client_0296' BELONGS_TO PeerGroup 'PG_1382'
# Relationship created: Client 'client_0297' BELONGS_TO PeerGroup 'PG_192'
# Relationship created: Client 'client_0298' BELONGS_TO PeerGroup 'PG_2157'
# Relationship created: Client 'client_0299' BELONGS_TO PeerGroup 'PG_508'
# Relationship created: Client 'client_0300' BELONGS_TO PeerGroup 'PG_115'
# Relationship created: Client 'client_0301' BELONGS_TO PeerGroup 'PG_442'
# Relationship created: Client 'client_0302' BELONGS_TO PeerGroup 'PG_3245'
# Relationship created: Client 'client_0303' BELONGS_TO PeerGroup 'PG_432'
# Relationship created: Client 'client_0304' BELONGS_TO PeerGroup 'PG_1018'
# Relationship created: Client 'client_0305' BELONGS_TO PeerGroup 'PG_797'
# Relationship created: Client 'client_0306' BELONGS_TO PeerGroup 'PG_1572'
# Relationship created: Client 'client_0307' BELONGS_TO PeerGroup 'PG_1222'
# Relationship created: Client 'client_0308' BELONGS_TO PeerGroup 'PG_825'
# Relationship created: Client 'client_0309' BELONGS_TO PeerGroup 'PG_2478'
# Relationship created: Client 'client_0310' BELONGS_TO PeerGroup 'PG_2803'
# Relationship created: Client 'client_0311' BELONGS_TO PeerGroup 'PG_724'
# Relationship created: Client 'client_0312' BELONGS_TO PeerGroup 'PG_1192'
# Relationship created: Client 'client_0313' BELONGS_TO PeerGroup 'PG_2639'
# Relationship created: Client 'client_0314' BELONGS_TO PeerGroup 'PG_1572'
# Relationship created: Client 'client_0315' BELONGS_TO PeerGroup 'PG_798'
# Relationship created: Client 'client_0316' BELONGS_TO PeerGroup 'PG_845'
# Relationship created: Client 'client_0317' BELONGS_TO PeerGroup 'PG_721'
# Relationship created: Client 'client_0318' BELONGS_TO PeerGroup 'PG_807'
# Relationship created: Client 'client_0319' BELONGS_TO PeerGroup 'PG_560'
# Relationship created: Client 'client_0320' BELONGS_TO PeerGroup 'PG_1362'
# Relationship created: Client 'client_0321' BELONGS_TO PeerGroup 'PG_025'
# Relationship created: Client 'client_0322' BELONGS_TO PeerGroup 'PG_1219'
# Relationship created: Client 'client_0323' BELONGS_TO PeerGroup 'PG_107'
# Relationship created: Client 'client_0324' BELONGS_TO PeerGroup 'PG_992'
# Relationship created: Client 'client_0325' BELONGS_TO PeerGroup 'PG_1642'
# Relationship created: Client 'client_0326' BELONGS_TO PeerGroup 'PG_1954'
# Relationship created: Client 'client_0327' BELONGS_TO PeerGroup 'PG_107'
# Relationship created: Client 'client_0328' BELONGS_TO PeerGroup 'PG_1038'
# Relationship created: Client 'client_0329' BELONGS_TO PeerGroup 'PG_4774'
# Relationship created: Client 'client_0330' BELONGS_TO PeerGroup 'PG_726'
# Relationship created: Client 'client_0331' BELONGS_TO PeerGroup 'PG_2882'
# Relationship created: Client 'client_0332' BELONGS_TO PeerGroup 'PG_1129'
# Relationship created: Client 'client_0333' BELONGS_TO PeerGroup 'PG_681'
# Relationship created: Client 'client_0334' BELONGS_TO PeerGroup 'PG_1532'
# Relationship created: Client 'client_0335' BELONGS_TO PeerGroup 'PG_069'
# Relationship created: Client 'client_0336' BELONGS_TO PeerGroup 'PG_584'
# Relationship created: Client 'client_0337' BELONGS_TO PeerGroup 'PG_894'
# Relationship created: Client 'client_0338' BELONGS_TO PeerGroup 'PG_1433'
# Relationship created: Client 'client_0339' BELONGS_TO PeerGroup 'PG_1414'
# Relationship created: Client 'client_0340' BELONGS_TO PeerGroup 'PG_764'
# Relationship created: Client 'client_0341' BELONGS_TO PeerGroup 'PG_2161'
# Relationship created: Client 'client_0342' BELONGS_TO PeerGroup 'PG_175'
# Relationship created: Client 'client_0343' BELONGS_TO PeerGroup 'PG_772'
# Relationship created: Client 'client_0344' BELONGS_TO PeerGroup 'PG_176'
# Relationship created: Client 'client_0345' BELONGS_TO PeerGroup 'PG_269'
# Relationship created: Client 'client_0346' BELONGS_TO PeerGroup 'PG_1524'
# Relationship created: Client 'client_0347' BELONGS_TO PeerGroup 'PG_1456'
# Relationship created: Client 'client_0348' BELONGS_TO PeerGroup 'PG_1411'
# Relationship created: Client 'client_0349' BELONGS_TO PeerGroup 'PG_546'
# Relationship created: Client 'client_0350' BELONGS_TO PeerGroup 'PG_2037'
# Relationship created: Client 'client_0351' BELONGS_TO PeerGroup 'PG_1457'
# Relationship created: Client 'client_0352' BELONGS_TO PeerGroup 'PG_514'
# Relationship created: Client 'client_0353' BELONGS_TO PeerGroup 'PG_3038'
# Relationship created: Client 'client_0354' BELONGS_TO PeerGroup 'PG_1672'
# Relationship created: Client 'client_0355' BELONGS_TO PeerGroup 'PG_220'
# Relationship created: Client 'client_0356' BELONGS_TO PeerGroup 'PG_3521'
# Relationship created: Client 'client_0357' BELONGS_TO PeerGroup 'PG_1132'
# Relationship created: Client 'client_0358' BELONGS_TO PeerGroup 'PG_2374'
# Relationship created: Client 'client_0359' BELONGS_TO PeerGroup 'PG_217'
# Relationship created: Client 'client_0360' BELONGS_TO PeerGroup 'PG_755'
# Relationship created: Client 'client_0361' BELONGS_TO PeerGroup 'PG_2439'
# Relationship created: Client 'client_0362' BELONGS_TO PeerGroup 'PG_531'
# Relationship created: Client 'client_0363' BELONGS_TO PeerGroup 'PG_852'
# Relationship created: Client 'client_0364' BELONGS_TO PeerGroup 'PG_212'
# Relationship created: Client 'client_0365' BELONGS_TO PeerGroup 'PG_3069'
# Relationship created: Client 'client_0366' BELONGS_TO PeerGroup 'PG_3892'
# Relationship created: Client 'client_0367' BELONGS_TO PeerGroup 'PG_1675'
# Relationship created: Client 'client_0368' BELONGS_TO PeerGroup 'PG_1214'
# Relationship created: Client 'client_0369' BELONGS_TO PeerGroup 'PG_622'
# Relationship created: Client 'client_0370' BELONGS_TO PeerGroup 'PG_1651'
# Relationship created: Client 'client_0371' BELONGS_TO PeerGroup 'PG_562'
# Relationship created: Client 'client_0372' BELONGS_TO PeerGroup 'PG_1717'
# Relationship created: Client 'client_0373' BELONGS_TO PeerGroup 'PG_1927'
# Relationship created: Client 'client_0374' BELONGS_TO PeerGroup 'PG_1495'
# Relationship created: Client 'client_0375' BELONGS_TO PeerGroup 'PG_4032'
# Relationship created: Client 'client_0376' BELONGS_TO PeerGroup 'PG_312'
# Relationship created: Client 'client_0377' BELONGS_TO PeerGroup 'PG_1076'
# Relationship created: Client 'client_0378' BELONGS_TO PeerGroup 'PG_612'
# Relationship created: Client 'client_0379' BELONGS_TO PeerGroup 'PG_835'
# Relationship created: Client 'client_0380' BELONGS_TO PeerGroup 'PG_1154'
# Relationship created: Client 'client_0381' BELONGS_TO PeerGroup 'PG_742'
# Relationship created: Client 'client_0382' BELONGS_TO PeerGroup 'PG_1112'
# Relationship created: Client 'client_0383' BELONGS_TO PeerGroup 'PG_1542'
# Relationship created: Client 'client_0384' BELONGS_TO PeerGroup 'PG_1720'
# Relationship created: Client 'client_0385' BELONGS_TO PeerGroup 'PG_1907'
# Relationship created: Client 'client_0386' BELONGS_TO PeerGroup 'PG_872'
# Relationship created: Client 'client_0387' BELONGS_TO PeerGroup 'PG_745'
# Relationship created: Client 'client_0388' BELONGS_TO PeerGroup 'PG_442'
# Relationship created: Client 'client_0389' BELONGS_TO PeerGroup 'PG_1242'
# Relationship created: Client 'client_0390' BELONGS_TO PeerGroup 'PG_382'
# Relationship created: Client 'client_0391' BELONGS_TO PeerGroup 'PG_386'
# Relationship created: Client 'client_0392' BELONGS_TO PeerGroup 'PG_591'
# Relationship created: Client 'client_0393' BELONGS_TO PeerGroup 'PG_773'
# Relationship created: Client 'client_0394' BELONGS_TO PeerGroup 'PG_032'
# Relationship created: Client 'client_0395' BELONGS_TO PeerGroup 'PG_389'
# Relationship created: Client 'client_0396' BELONGS_TO PeerGroup 'PG_1505'
# Relationship created: Client 'client_0397' BELONGS_TO PeerGroup 'PG_1257'
# Relationship created: Client 'client_0398' BELONGS_TO PeerGroup 'PG_182'
# Relationship created: Client 'client_0399' BELONGS_TO PeerGroup 'PG_044'
# Relationship created: Client 'client_0400' BELONGS_TO PeerGroup 'PG_391'
# Relationship created: Client 'client_0401' BELONGS_TO PeerGroup 'PG_142'
# Relationship created: Client 'client_0402' BELONGS_TO PeerGroup 'PG_6731'
# Relationship created: Client 'client_0403' BELONGS_TO PeerGroup 'PG_342'
# Relationship created: Client 'client_0404' BELONGS_TO PeerGroup 'PG_1054'
# Relationship created: Client 'client_0405' BELONGS_TO PeerGroup 'PG_1591'
# Relationship created: Client 'client_0406' BELONGS_TO PeerGroup 'PG_652'
# Relationship created: Client 'client_0407' BELONGS_TO PeerGroup 'PG_641'
# Relationship created: Client 'client_0408' BELONGS_TO PeerGroup 'PG_1382'
# Relationship created: Client 'client_0409' BELONGS_TO PeerGroup 'PG_1402'
# Relationship created: Client 'client_0410' BELONGS_TO PeerGroup 'PG_365'
# Relationship created: Client 'client_0411' BELONGS_TO PeerGroup 'PG_192'
# Relationship created: Client 'client_0412' BELONGS_TO PeerGroup 'PG_1262'
# Relationship created: Client 'client_0413' BELONGS_TO PeerGroup 'PG_367'
# Relationship created: Client 'client_0414' BELONGS_TO PeerGroup 'PG_859'
# Relationship created: Client 'client_0415' BELONGS_TO PeerGroup 'PG_2882'
# Relationship created: Client 'client_0416' BELONGS_TO PeerGroup 'PG_508'
# Relationship created: Client 'client_0417' BELONGS_TO PeerGroup 'PG_459'
# Relationship created: Client 'client_0418' BELONGS_TO PeerGroup 'PG_1115'
# Relationship created: Client 'client_0419' BELONGS_TO PeerGroup 'PG_1021'
# Relationship created: Client 'client_0420' BELONGS_TO PeerGroup 'PG_266'
# Relationship created: Client 'client_0421' BELONGS_TO PeerGroup 'PG_291'
# Relationship created: Client 'client_0422' BELONGS_TO PeerGroup 'PG_1712'
# Relationship created: Client 'client_0423' BELONGS_TO PeerGroup 'PG_697'
# Relationship created: Client 'client_0424' BELONGS_TO PeerGroup 'PG_816'
# Relationship created: Client 'client_0425' BELONGS_TO PeerGroup 'PG_1437'
# Relationship created: Client 'client_0426' BELONGS_TO PeerGroup 'PG_748'
# Relationship created: Client 'client_0427' BELONGS_TO PeerGroup 'PG_551'
# Relationship created: Client 'client_0428' BELONGS_TO PeerGroup 'PG_592'
# Relationship created: Client 'client_0429' BELONGS_TO PeerGroup 'PG_1296'
# Relationship created: Client 'client_0430' BELONGS_TO PeerGroup 'PG_242'
# Relationship created: Client 'client_0431' BELONGS_TO PeerGroup 'PG_1047'
# Relationship created: Client 'client_0432' BELONGS_TO PeerGroup 'PG_1182'
# Relationship created: Client 'client_0433' BELONGS_TO PeerGroup 'PG_1095'
# Relationship created: Client 'client_0434' BELONGS_TO PeerGroup 'PG_767'
# Relationship created: Client 'client_0435' BELONGS_TO PeerGroup 'PG_2028'
# Relationship created: Client 'client_0436' BELONGS_TO PeerGroup 'PG_1098'
# Relationship created: Client 'client_0437' BELONGS_TO PeerGroup 'PG_3553'
# Relationship created: Client 'client_0438' BELONGS_TO PeerGroup 'PG_387'
# Relationship created: Client 'client_0439' BELONGS_TO PeerGroup 'PG_947'
# Relationship created: Client 'client_0440' BELONGS_TO PeerGroup 'PG_081'
# Relationship created: Client 'client_0441' BELONGS_TO PeerGroup 'PG_042'
# Relationship created: Client 'client_0442' BELONGS_TO PeerGroup 'PG_902'
# Relationship created: Client 'client_0443' BELONGS_TO PeerGroup 'PG_406'
# Relationship created: Client 'client_0444' BELONGS_TO PeerGroup 'PG_3528'
# Relationship created: Client 'client_0445' BELONGS_TO PeerGroup 'PG_1252'
# Relationship created: Client 'client_0446' BELONGS_TO PeerGroup 'PG_689'
# Relationship created: Client 'client_0447' BELONGS_TO PeerGroup 'PG_742'
# Relationship created: Client 'client_0448' BELONGS_TO PeerGroup 'PG_984'
# Relationship created: Client 'client_0449' BELONGS_TO PeerGroup 'PG_1209'
# Relationship created: Client 'client_0450' BELONGS_TO PeerGroup 'PG_905'
# Relationship created: Client 'client_0451' BELONGS_TO PeerGroup 'PG_1102'
# Relationship created: Client 'client_0452' BELONGS_TO PeerGroup 'PG_205'
# Relationship created: Client 'client_0453' BELONGS_TO PeerGroup 'PG_1727'
# Relationship created: Client 'client_0454' BELONGS_TO PeerGroup 'PG_485'
# Relationship created: Client 'client_0455' BELONGS_TO PeerGroup 'PG_1485'
# Relationship created: Client 'client_0456' BELONGS_TO PeerGroup 'PG_821'
# Relationship created: Client 'client_0457' BELONGS_TO PeerGroup 'PG_361'
# Relationship created: Client 'client_0458' BELONGS_TO PeerGroup 'PG_1736'
# Relationship created: Client 'client_0459' BELONGS_TO PeerGroup 'PG_572'
# Relationship created: Client 'client_0460' BELONGS_TO PeerGroup 'PG_1614'
# Relationship created: Client 'client_0461' BELONGS_TO PeerGroup 'PG_1245'
# Relationship created: Client 'client_0462' BELONGS_TO PeerGroup 'PG_4912'
# Relationship created: Client 'client_0463' BELONGS_TO PeerGroup 'PG_1209'
# Relationship created: Client 'client_0464' BELONGS_TO PeerGroup 'PG_755'
# Relationship created: Client 'client_0465' BELONGS_TO PeerGroup 'PG_1562'
# Relationship created: Client 'client_0466' BELONGS_TO PeerGroup 'PG_565'
# Relationship created: Client 'client_0467' BELONGS_TO PeerGroup 'PG_2177'
# Relationship created: Client 'client_0468' BELONGS_TO PeerGroup 'PG_1484'
# Relationship created: Client 'client_0469' BELONGS_TO PeerGroup 'PG_102'
# Relationship created: Client 'client_0470' BELONGS_TO PeerGroup 'PG_577'
# Relationship created: Client 'client_0471' BELONGS_TO PeerGroup 'PG_1092'
# Relationship created: Client 'client_0472' BELONGS_TO PeerGroup 'PG_1415'
# Relationship created: Client 'client_0473' BELONGS_TO PeerGroup 'PG_902'
# Relationship created: Client 'client_0474' BELONGS_TO PeerGroup 'PG_009'
# Relationship created: Client 'client_0475' BELONGS_TO PeerGroup 'PG_622'
# Relationship created: Client 'client_0476' BELONGS_TO PeerGroup 'PG_1072'
# Relationship created: Client 'client_0477' BELONGS_TO PeerGroup 'PG_1416'
# Relationship created: Client 'client_0478' BELONGS_TO PeerGroup 'PG_3484'
# Relationship created: Client 'client_0479' BELONGS_TO PeerGroup 'PG_739'
# Relationship created: Client 'client_0480' BELONGS_TO PeerGroup 'PG_516'
# Relationship created: Client 'client_0481' BELONGS_TO PeerGroup 'PG_261'
# Relationship created: Client 'client_0482' BELONGS_TO PeerGroup 'PG_1622'
# Relationship created: Client 'client_0483' BELONGS_TO PeerGroup 'PG_715'
# Relationship created: Client 'client_0484' BELONGS_TO PeerGroup 'PG_3438'
# Relationship created: Client 'client_0485' BELONGS_TO PeerGroup 'PG_726'
# Relationship created: Client 'client_0486' BELONGS_TO PeerGroup 'PG_190'
# Relationship created: Client 'client_0487' BELONGS_TO PeerGroup 'PG_2352'
# Relationship created: Client 'client_0488' BELONGS_TO PeerGroup 'PG_737'
# Relationship created: Client 'client_0489' BELONGS_TO PeerGroup 'PG_1374'
# Relationship created: Client 'client_0490' BELONGS_TO PeerGroup 'PG_668'
# Relationship created: Client 'client_0491' BELONGS_TO PeerGroup 'PG_1352'
# Relationship created: Client 'client_0492' BELONGS_TO PeerGroup 'PG_077'
# Relationship created: Client 'client_0493' BELONGS_TO PeerGroup 'PG_242'
# Relationship created: Client 'client_0494' BELONGS_TO PeerGroup 'PG_406'
# Relationship created: Client 'client_0495' BELONGS_TO PeerGroup 'PG_341'
# Relationship created: Client 'client_0496' BELONGS_TO PeerGroup 'PG_011'
# Relationship created: Client 'client_0497' BELONGS_TO PeerGroup 'PG_2429'
# Relationship created: Client 'client_0498' BELONGS_TO PeerGroup 'PG_749'
# Relationship created: Client 'client_0499' BELONGS_TO PeerGroup 'PG_1539'
# Relationship created: Client 'client_0500' BELONGS_TO PeerGroup 'PG_782'
# Relationship created: Client 'client_0501' BELONGS_TO PeerGroup 'PG_764'
# Relationship created: Client 'client_0502' BELONGS_TO PeerGroup 'PG_009'
# Relationship created: Client 'client_0503' BELONGS_TO PeerGroup 'PG_1659'
# Relationship created: Client 'client_0504' BELONGS_TO PeerGroup 'PG_1128'
# Relationship created: Client 'client_0505' BELONGS_TO PeerGroup 'PG_1299'
# Relationship created: Client 'client_0506' BELONGS_TO PeerGroup 'PG_3212'
# Relationship created: Client 'client_0507' BELONGS_TO PeerGroup 'PG_3262'
# Relationship created: Client 'client_0508' BELONGS_TO PeerGroup 'PG_1191'
# Relationship created: Client 'client_0509' BELONGS_TO PeerGroup 'PG_357'
# Relationship created: Client 'client_0510' BELONGS_TO PeerGroup 'PG_1612'
# Relationship created: Client 'client_0511' BELONGS_TO PeerGroup 'PG_1513'
# Relationship created: Client 'client_0512' BELONGS_TO PeerGroup 'PG_1412'
# Relationship created: Client 'client_0513' BELONGS_TO PeerGroup 'PG_1649'
# Relationship created: Client 'client_0514' BELONGS_TO PeerGroup 'PG_1402'
# Relationship created: Client 'client_0515' BELONGS_TO PeerGroup 'PG_1227'
# Relationship created: Client 'client_0516' BELONGS_TO PeerGroup 'PG_032'
# Relationship created: Client 'client_0517' BELONGS_TO PeerGroup 'PG_794'
# Relationship created: Client 'client_0518' BELONGS_TO PeerGroup 'PG_2911'
# Relationship created: Client 'client_0519' BELONGS_TO PeerGroup 'PG_1425'
# Relationship created: Client 'client_0520' BELONGS_TO PeerGroup 'PG_1403'
# Relationship created: Client 'client_0521' BELONGS_TO PeerGroup 'PG_1361'
# Relationship created: Client 'client_0522' BELONGS_TO PeerGroup 'PG_1558'
# Relationship created: Client 'client_0523' BELONGS_TO PeerGroup 'PG_3422'
# Relationship created: Client 'client_0524' BELONGS_TO PeerGroup 'PG_202'
# Relationship created: Client 'client_0525' BELONGS_TO PeerGroup 'PG_985'
# Relationship created: Client 'client_0526' BELONGS_TO PeerGroup 'PG_271'
# Relationship created: Client 'client_0527' BELONGS_TO PeerGroup 'PG_1012'
# Relationship created: Client 'client_0528' BELONGS_TO PeerGroup 'PG_237'
# Relationship created: Client 'client_0529' BELONGS_TO PeerGroup 'PG_227'
# Relationship created: Client 'client_0530' BELONGS_TO PeerGroup 'PG_1086'
# Relationship created: Client 'client_0531' BELONGS_TO PeerGroup 'PG_2836'
# Relationship created: Client 'client_0532' BELONGS_TO PeerGroup 'PG_1628'
# Relationship created: Client 'client_0533' BELONGS_TO PeerGroup 'PG_612'
# Relationship created: Client 'client_0534' BELONGS_TO PeerGroup 'PG_1407'
# Relationship created: Client 'client_0535' BELONGS_TO PeerGroup 'PG_1355'
# Relationship created: Client 'client_0536' BELONGS_TO PeerGroup 'PG_1012'
# Relationship created: Client 'client_0537' BELONGS_TO PeerGroup 'PG_1713'
# Relationship created: Client 'client_0538' BELONGS_TO PeerGroup 'PG_1208'
# Relationship created: Client 'client_0539' BELONGS_TO PeerGroup 'PG_1762'
# Relationship created: Client 'client_0540' BELONGS_TO PeerGroup 'PG_301'
# Relationship created: Client 'client_0541' BELONGS_TO PeerGroup 'PG_3421'
# Relationship created: Client 'client_0542' BELONGS_TO PeerGroup 'PG_712'
# Relationship created: Client 'client_0543' BELONGS_TO PeerGroup 'PG_635'
# Relationship created: Client 'client_0544' BELONGS_TO PeerGroup 'PG_2177'
# Relationship created: Client 'client_0545' BELONGS_TO PeerGroup 'PG_3475'
# Relationship created: Client 'client_0546' BELONGS_TO PeerGroup 'PG_695'
# Relationship created: Client 'client_0547' BELONGS_TO PeerGroup 'PG_345'
# Relationship created: Client 'client_0548' BELONGS_TO PeerGroup 'PG_1019'
# Relationship created: Client 'client_0549' BELONGS_TO PeerGroup 'PG_235'
# Relationship created: Client 'client_0550' BELONGS_TO PeerGroup 'PG_1270'
# Relationship created: Client 'client_0551' BELONGS_TO PeerGroup 'PG_2975'
# Relationship created: Client 'client_0552' BELONGS_TO PeerGroup 'PG_452'
# Relationship created: Client 'client_0553' BELONGS_TO PeerGroup 'PG_947'
# Relationship created: Client 'client_0554' BELONGS_TO PeerGroup 'PG_472'
# Relationship created: Client 'client_0555' BELONGS_TO PeerGroup 'PG_022'
# Relationship created: Client 'client_0556' BELONGS_TO PeerGroup 'PG_074'
# Relationship created: Client 'client_0557' BELONGS_TO PeerGroup 'PG_755'
# Relationship created: Client 'client_0558' BELONGS_TO PeerGroup 'PG_662'
# Relationship created: Client 'client_0559' BELONGS_TO PeerGroup 'PG_1965'
# Relationship created: Client 'client_0560' BELONGS_TO PeerGroup 'PG_942'
# Relationship created: Client 'client_0561' BELONGS_TO PeerGroup 'PG_400'
# Relationship created: Client 'client_0562' BELONGS_TO PeerGroup 'PG_1478'
# Relationship created: Client 'client_0563' BELONGS_TO PeerGroup 'PG_575'
# Relationship created: Client 'client_0564' BELONGS_TO PeerGroup 'PG_141'
# Relationship created: Client 'client_0565' BELONGS_TO PeerGroup 'PG_2186'
# Relationship created: Client 'client_0566' BELONGS_TO PeerGroup 'PG_1682'
# Relationship created: Client 'client_0567' BELONGS_TO PeerGroup 'PG_3038'
# Relationship created: Client 'client_0568' BELONGS_TO PeerGroup 'PG_3061'
# Relationship created: Client 'client_0569' BELONGS_TO PeerGroup 'PG_799'
# Relationship created: Client 'client_0570' BELONGS_TO PeerGroup 'PG_2624'
# Relationship created: Client 'client_0571' BELONGS_TO PeerGroup 'PG_1504'
# Relationship created: Client 'client_0572' BELONGS_TO PeerGroup 'PG_1531'
# Relationship created: Client 'client_0573' BELONGS_TO PeerGroup 'PG_1153'
# Relationship created: Client 'client_0574' BELONGS_TO PeerGroup 'PG_538'
# Relationship created: Client 'client_0575' BELONGS_TO PeerGroup 'PG_5802'
# Relationship created: Client 'client_0576' BELONGS_TO PeerGroup 'PG_692'
# Relationship created: Client 'client_0577' BELONGS_TO PeerGroup 'PG_1162'
# Relationship created: Client 'client_0578' BELONGS_TO PeerGroup 'PG_1974'
# Relationship created: Client 'client_0579' BELONGS_TO PeerGroup 'PG_756'
# Relationship created: Client 'client_0580' BELONGS_TO PeerGroup 'PG_1764'
# Relationship created: Client 'client_0581' BELONGS_TO PeerGroup 'PG_092'
# Relationship created: Client 'client_0582' BELONGS_TO PeerGroup 'PG_272'
# Relationship created: Client 'client_0583' BELONGS_TO PeerGroup 'PG_3789'
# Relationship created: Client 'client_0584' BELONGS_TO PeerGroup 'PG_1144'
# Relationship created: Client 'client_0585' BELONGS_TO PeerGroup 'PG_384'
# Relationship created: Client 'client_0586' BELONGS_TO PeerGroup 'PG_3330'
# Relationship created: Client 'client_0587' BELONGS_TO PeerGroup 'PG_972'
# Relationship created: Client 'client_0588' BELONGS_TO PeerGroup 'PG_713'
# Relationship created: Client 'client_0589' BELONGS_TO PeerGroup 'PG_902'
# Relationship created: Client 'client_0590' BELONGS_TO PeerGroup 'PG_972'
# Relationship created: Client 'client_0591' BELONGS_TO PeerGroup 'PG_1752'
# Relationship created: Client 'client_0592' BELONGS_TO PeerGroup 'PG_3191'
# Relationship created: Client 'client_0593' BELONGS_TO PeerGroup 'PG_1292'
# Relationship created: Client 'client_0594' BELONGS_TO PeerGroup 'PG_1412'
# Relationship created: Client 'client_0595' BELONGS_TO PeerGroup 'PG_2829'
# Relationship created: Client 'client_0596' BELONGS_TO PeerGroup 'PG_762'
# Relationship created: Client 'client_0597' BELONGS_TO PeerGroup 'PG_1642'
# Relationship created: Client 'client_0598' BELONGS_TO PeerGroup 'PG_595'
# Relationship created: Client 'client_0599' BELONGS_TO PeerGroup 'PG_584'
# Relationship created: Client 'client_0600' BELONGS_TO PeerGroup 'PG_2697'
# Relationship created: Client 'client_0601' BELONGS_TO PeerGroup 'PG_009'
# Relationship created: Client 'client_0602' BELONGS_TO PeerGroup 'PG_202'
# Relationship created: Client 'client_0603' BELONGS_TO PeerGroup 'PG_3134'
# Relationship created: Client 'client_0604' BELONGS_TO PeerGroup 'PG_252'
# Relationship created: Client 'client_0605' BELONGS_TO PeerGroup 'PG_982'
# Relationship created: Client 'client_0606' BELONGS_TO PeerGroup 'PG_818'
# Relationship created: Client 'client_0607' BELONGS_TO PeerGroup 'PG_1032'
# Relationship created: Client 'client_0608' BELONGS_TO PeerGroup 'PG_447'
# Relationship created: Client 'client_0609' BELONGS_TO PeerGroup 'PG_729'
# Relationship created: Client 'client_0610' BELONGS_TO PeerGroup 'PG_739'
# Relationship created: Client 'client_0611' BELONGS_TO PeerGroup 'PG_1217'
# Relationship created: Client 'client_0612' BELONGS_TO PeerGroup 'PG_1377'
# Relationship created: Client 'client_0613' BELONGS_TO PeerGroup 'PG_167'
# Relationship created: Client 'client_0614' BELONGS_TO PeerGroup 'PG_327'
# Relationship created: Client 'client_0615' BELONGS_TO PeerGroup 'PG_1655'
# Relationship created: Client 'client_0616' BELONGS_TO PeerGroup 'PG_453'
# Relationship created: Client 'client_0617' BELONGS_TO PeerGroup 'PG_996'
# Relationship created: Client 'client_0618' BELONGS_TO PeerGroup 'PG_1556'
# Relationship created: Client 'client_0619' BELONGS_TO PeerGroup 'PG_149'
# Relationship created: Client 'client_0620' BELONGS_TO PeerGroup 'PG_1018'
# Relationship created: Client 'client_0621' BELONGS_TO PeerGroup 'PG_862'
# Relationship created: Client 'client_0622' BELONGS_TO PeerGroup 'PG_242'
# Relationship created: Client 'client_0623' BELONGS_TO PeerGroup 'PG_1596'
# Relationship created: Client 'client_0624' BELONGS_TO PeerGroup 'PG_188'
# Relationship created: Client 'client_0625' BELONGS_TO PeerGroup 'PG_1112'
# Relationship created: Client 'client_0626' BELONGS_TO PeerGroup 'PG_859'
# Relationship created: Client 'client_0627' BELONGS_TO PeerGroup 'PG_3525'
# Relationship created: Client 'client_0628' BELONGS_TO PeerGroup 'PG_1227'
# Relationship created: Client 'client_0629' BELONGS_TO PeerGroup 'PG_2414'
# Relationship created: Client 'client_0630' BELONGS_TO PeerGroup 'PG_565'
# Relationship created: Client 'client_0631' BELONGS_TO PeerGroup 'PG_167'
# Relationship created: Client 'client_0632' BELONGS_TO PeerGroup 'PG_1397'
# Relationship created: Client 'client_0633' BELONGS_TO PeerGroup 'PG_344'
# Relationship created: Client 'client_0634' BELONGS_TO PeerGroup 'PG_852'
# Relationship created: Client 'client_0635' BELONGS_TO PeerGroup 'PG_522'
# Relationship created: Client 'client_0636' BELONGS_TO PeerGroup 'PG_1681'
# Relationship created: Client 'client_0637' BELONGS_TO PeerGroup 'PG_2257'
# Relationship created: Client 'client_0638' BELONGS_TO PeerGroup 'PG_3086'
# Relationship created: Client 'client_0639' BELONGS_TO PeerGroup 'PG_324'
# Relationship created: Client 'client_0640' BELONGS_TO PeerGroup 'PG_1953'
# Relationship created: Client 'client_0641' BELONGS_TO PeerGroup 'PG_512'
# Relationship created: Client 'client_0642' BELONGS_TO PeerGroup 'PG_067'
# Relationship created: Client 'client_0643' BELONGS_TO PeerGroup 'PG_1677'
# Relationship created: Client 'client_0644' BELONGS_TO PeerGroup 'PG_1523'
# Relationship created: Client 'client_0645' BELONGS_TO PeerGroup 'PG_638'
# Relationship created: Client 'client_0646' BELONGS_TO PeerGroup 'PG_141'
# Relationship created: Client 'client_0647' BELONGS_TO PeerGroup 'PG_023'
# Relationship created: Client 'client_0648' BELONGS_TO PeerGroup 'PG_1847'
# Relationship created: Client 'client_0649' BELONGS_TO PeerGroup 'PG_1116'
# Relationship created: Client 'client_0650' BELONGS_TO PeerGroup 'PG_332'
# Relationship created: Client 'client_0651' BELONGS_TO PeerGroup 'PG_424'
# ...
# Relationship created: Client 'client_4784' BELONGS_TO PeerGroup 'PG_1302'
# Relationship created: Client 'client_4785' BELONGS_TO PeerGroup 'PG_217'
# Relationship created: Client 'client_4786' BELONGS_TO PeerGroup 'PG_1077'
# Relationship created: Client 'client_4787' BELONGS_TO PeerGroup 'PG_2492'
# Relationship created: Client 'client_4788' BELONGS_TO PeerGroup 'PG_756'
# Relationship created: Client 'client_4789' BELONGS_TO PeerGroup 'PG_1226'
# Relationship created: Client 'client_4790' BELONGS_TO PeerGroup 'PG_932'
# Relationship created: Client 'client_4791' BELONGS_TO PeerGroup 'PG_742'
# Relationship created: Client 'client_4792' BELONGS_TO PeerGroup 'PG_965'
# Relationship created: Client 'client_4793' BELONGS_TO PeerGroup 'PG_3108'
# Relationship created: Client 'client_4794' BELONGS_TO PeerGroup 'PG_959'
# Relationship created: Client 'client_4795' BELONGS_TO PeerGroup 'PG_2805'
# Relationship created: Client 'client_4796' BELONGS_TO PeerGroup 'PG_975'
# Relationship created: Client 'client_4797' BELONGS_TO PeerGroup 'PG_842'
# Relationship created: Client 'client_4798' BELONGS_TO PeerGroup 'PG_2912'
# Relationship created: Client 'client_4799' BELONGS_TO PeerGroup 'PG_932'
# Relationship created: Client 'client_4800' BELONGS_TO PeerGroup 'PG_1683'
# Relationship created: Client 'client_4801' BELONGS_TO PeerGroup 'PG_1869'
# Relationship created: Client 'client_4802' BELONGS_TO PeerGroup 'PG_595'
# Relationship created: Client 'client_4803' BELONGS_TO PeerGroup 'PG_1107'
# Relationship created: Client 'client_4804' BELONGS_TO PeerGroup 'PG_1249'
# Relationship created: Client 'client_4805' BELONGS_TO PeerGroup 'PG_1636'
# Relationship created: Client 'client_4806' BELONGS_TO PeerGroup 'PG_635'
# Relationship created: Client 'client_4807' BELONGS_TO PeerGroup 'PG_142'
# Relationship created: Client 'client_4808' BELONGS_TO PeerGroup 'PG_509'
# Relationship created: Client 'client_4809' BELONGS_TO PeerGroup 'PG_056'
# Relationship created: Client 'client_4810' BELONGS_TO PeerGroup 'PG_1679'
# Relationship created: Client 'client_4811' BELONGS_TO PeerGroup 'PG_1092'
# Relationship created: Client 'client_4812' BELONGS_TO PeerGroup 'PG_2862'
# Relationship created: Client 'client_4813' BELONGS_TO PeerGroup 'PG_482'
# Relationship created: Client 'client_4814' BELONGS_TO PeerGroup 'PG_3151'
# Relationship created: Client 'client_4815' BELONGS_TO PeerGroup 'PG_1431'
# Relationship created: Client 'client_4816' BELONGS_TO PeerGroup 'PG_445'
# Relationship created: Client 'client_4817' BELONGS_TO PeerGroup 'PG_1007'
# Relationship created: Client 'client_4818' BELONGS_TO PeerGroup 'PG_564'
# Relationship created: Client 'client_4819' BELONGS_TO PeerGroup 'PG_2432'
# Relationship created: Client 'client_4820' BELONGS_TO PeerGroup 'PG_1635'
# Relationship created: Client 'client_4821' BELONGS_TO PeerGroup 'PG_741'
# Relationship created: Client 'client_4822' BELONGS_TO PeerGroup 'PG_871'
# Relationship created: Client 'client_4823' BELONGS_TO PeerGroup 'PG_237'
# Relationship created: Client 'client_4824' BELONGS_TO PeerGroup 'PG_1456'
# Relationship created: Client 'client_4825' BELONGS_TO PeerGroup 'PG_3131'
# Relationship created: Client 'client_4826' BELONGS_TO PeerGroup 'PG_1891'
# Relationship created: Client 'client_4827' BELONGS_TO PeerGroup 'PG_1421'
# Relationship created: Client 'client_4828' BELONGS_TO PeerGroup 'PG_368'
# Relationship created: Client 'client_4829' BELONGS_TO PeerGroup 'PG_2737'
# Relationship created: Client 'client_4830' BELONGS_TO PeerGroup 'PG_1732'
# Relationship created: Client 'client_4831' BELONGS_TO PeerGroup 'PG_1305'
# Relationship created: Client 'client_4832' BELONGS_TO PeerGroup 'PG_1479'
# Relationship created: Client 'client_4833' BELONGS_TO PeerGroup 'PG_1662'
# Relationship created: Client 'client_4834' BELONGS_TO PeerGroup 'PG_556'
# Relationship created: Client 'client_4835' BELONGS_TO PeerGroup 'PG_1599'
# Relationship created: Client 'client_4836' BELONGS_TO PeerGroup 'PG_1431'
# Relationship created: Client 'client_4837' BELONGS_TO PeerGroup 'PG_1205'
# Relationship created: Client 'client_4838' BELONGS_TO PeerGroup 'PG_1551'
# Relationship created: Client 'client_4839' BELONGS_TO PeerGroup 'PG_462'
# Relationship created: Client 'client_4840' BELONGS_TO PeerGroup 'PG_5175'
# Relationship created: Client 'client_4841' BELONGS_TO PeerGroup 'PG_531'
# Relationship created: Client 'client_4842' BELONGS_TO PeerGroup 'PG_707'
# Relationship created: Client 'client_4843' BELONGS_TO PeerGroup 'PG_847'
# Relationship created: Client 'client_4844' BELONGS_TO PeerGroup 'PG_599'
# Relationship created: Client 'client_4845' BELONGS_TO PeerGroup 'PG_2347'
# Relationship created: Client 'client_4846' BELONGS_TO PeerGroup 'PG_922'
# Relationship created: Client 'client_4847' BELONGS_TO PeerGroup 'PG_059'
# Relationship created: Client 'client_4848' BELONGS_TO PeerGroup 'PG_447'
# Relationship created: Client 'client_4849' BELONGS_TO PeerGroup 'PG_1023'
# Relationship created: Client 'client_4850' BELONGS_TO PeerGroup 'PG_1518'
# Relationship created: Client 'client_4851' BELONGS_TO PeerGroup 'PG_2321'
# Relationship created: Client 'client_4852' BELONGS_TO PeerGroup 'PG_1071'
# Relationship created: Client 'client_4853' BELONGS_TO PeerGroup 'PG_2435'
# Relationship created: Client 'client_4854' BELONGS_TO PeerGroup 'PG_1582'
# Relationship created: Client 'client_4855' BELONGS_TO PeerGroup 'PG_635'
# Relationship created: Client 'client_4856' BELONGS_TO PeerGroup 'PG_533'
# Relationship created: Client 'client_4857' BELONGS_TO PeerGroup 'PG_1631'
# Relationship created: Client 'client_4858' BELONGS_TO PeerGroup 'PG_1450'
# Relationship created: Client 'client_4859' BELONGS_TO PeerGroup 'PG_662'
# Relationship created: Client 'client_4860' BELONGS_TO PeerGroup 'PG_2844'
# Relationship created: Client 'client_4861' BELONGS_TO PeerGroup 'PG_518'
# Relationship created: Client 'client_4862' BELONGS_TO PeerGroup 'PG_246'
# Relationship created: Client 'client_4863' BELONGS_TO PeerGroup 'PG_1238'
# Relationship created: Client 'client_4864' BELONGS_TO PeerGroup 'PG_3247'
# Relationship created: Client 'client_4865' BELONGS_TO PeerGroup 'PG_032'
# Relationship created: Client 'client_4866' BELONGS_TO PeerGroup 'PG_035'
# Relationship created: Client 'client_4867' BELONGS_TO PeerGroup 'PG_489'
# Relationship created: Client 'client_4868' BELONGS_TO PeerGroup 'PG_086'
# Relationship created: Client 'client_4869' BELONGS_TO PeerGroup 'PG_001'
# Relationship created: Client 'client_4870' BELONGS_TO PeerGroup 'PG_182'
# Relationship created: Client 'client_4871' BELONGS_TO PeerGroup 'PG_1749'
# Relationship created: Client 'client_4872' BELONGS_TO PeerGroup 'PG_1417'
# Relationship created: Client 'client_4873' BELONGS_TO PeerGroup 'PG_5325'
# Relationship created: Client 'client_4874' BELONGS_TO PeerGroup 'PG_1592'
# Relationship created: Client 'client_4875' BELONGS_TO PeerGroup 'PG_218'
# Relationship created: Client 'client_4876' BELONGS_TO PeerGroup 'PG_1082'
# Relationship created: Client 'client_4877' BELONGS_TO PeerGroup 'PG_709'
# Relationship created: Client 'client_4878' BELONGS_TO PeerGroup 'PG_172'
# Relationship created: Client 'client_4879' BELONGS_TO PeerGroup 'PG_1225'
# Relationship created: Client 'client_4880' BELONGS_TO PeerGroup 'PG_1075'
# Relationship created: Client 'client_4881' BELONGS_TO PeerGroup 'PG_1385'
# Relationship created: Client 'client_4882' BELONGS_TO PeerGroup 'PG_1337'
# Relationship created: Client 'client_4883' BELONGS_TO PeerGroup 'PG_1164'
# Relationship created: Client 'client_4884' BELONGS_TO PeerGroup 'PG_1498'
# Relationship created: Client 'client_4885' BELONGS_TO PeerGroup 'PG_217'
# Relationship created: Client 'client_4886' BELONGS_TO PeerGroup 'PG_4640'
# Relationship created: Client 'client_4887' BELONGS_TO PeerGroup 'PG_498'
# Relationship created: Client 'client_4888' BELONGS_TO PeerGroup 'PG_902'
# Relationship created: Client 'client_4889' BELONGS_TO PeerGroup 'PG_514'
# Relationship created: Client 'client_4890' BELONGS_TO PeerGroup 'PG_424'
# Relationship created: Client 'client_4891' BELONGS_TO PeerGroup 'PG_4105'
# Relationship created: Client 'client_4892' BELONGS_TO PeerGroup 'PG_1694'
# Relationship created: Client 'client_4893' BELONGS_TO PeerGroup 'PG_352'
# Relationship created: Client 'client_4894' BELONGS_TO PeerGroup 'PG_836'
# Relationship created: Client 'client_4895' BELONGS_TO PeerGroup 'PG_2909'
# Relationship created: Client 'client_4896' BELONGS_TO PeerGroup 'PG_1535'
# Relationship created: Client 'client_4897' BELONGS_TO PeerGroup 'PG_677'
# Relationship created: Client 'client_4898' BELONGS_TO PeerGroup 'PG_3856'
# Relationship created: Client 'client_4899' BELONGS_TO PeerGroup 'PG_369'
# Relationship created: Client 'client_4900' BELONGS_TO PeerGroup 'PG_1675'
# Relationship created: Client 'client_4901' BELONGS_TO PeerGroup 'PG_774'
# Relationship created: Client 'client_4902' BELONGS_TO PeerGroup 'PG_1447'
# Relationship created: Client 'client_4903' BELONGS_TO PeerGroup 'PG_332'
# Relationship created: Client 'client_4904' BELONGS_TO PeerGroup 'PG_698'
# Relationship created: Client 'client_4905' BELONGS_TO PeerGroup 'PG_1412'
# Relationship created: Client 'client_4906' BELONGS_TO PeerGroup 'PG_1707'
# Relationship created: Client 'client_4907' BELONGS_TO PeerGroup 'PG_1310'
# Relationship created: Client 'client_4908' BELONGS_TO PeerGroup 'PG_082'
# Relationship created: Client 'client_4909' BELONGS_TO PeerGroup 'PG_1758'
# Relationship created: Client 'client_4910' BELONGS_TO PeerGroup 'PG_1222'
# Relationship created: Client 'client_4911' BELONGS_TO PeerGroup 'PG_325'
# Relationship created: Client 'client_4912' BELONGS_TO PeerGroup 'PG_252'
# Relationship created: Client 'client_4913' BELONGS_TO PeerGroup 'PG_3275'
# Relationship created: Client 'client_4914' BELONGS_TO PeerGroup 'PG_1404'
# Relationship created: Client 'client_4915' BELONGS_TO PeerGroup 'PG_3362'
# Relationship created: Client 'client_4916' BELONGS_TO PeerGroup 'PG_1753'
# Relationship created: Client 'client_4917' BELONGS_TO PeerGroup 'PG_657'
# Relationship created: Client 'client_4918' BELONGS_TO PeerGroup 'PG_137'
# Relationship created: Client 'client_4919' BELONGS_TO PeerGroup 'PG_2896'
# Relationship created: Client 'client_4920' BELONGS_TO PeerGroup 'PG_579'
# Relationship created: Client 'client_4921' BELONGS_TO PeerGroup 'PG_192'
# Relationship created: Client 'client_4922' BELONGS_TO PeerGroup 'PG_1454'
# Relationship created: Client 'client_4923' BELONGS_TO PeerGroup 'PG_1515'
# Relationship created: Client 'client_4924' BELONGS_TO PeerGroup 'PG_1324'
# Relationship created: Client 'client_4925' BELONGS_TO PeerGroup 'PG_693'
# Relationship created: Client 'client_4926' BELONGS_TO PeerGroup 'PG_963'
# Relationship created: Client 'client_4927' BELONGS_TO PeerGroup 'PG_4009'
# Relationship created: Client 'client_4928' BELONGS_TO PeerGroup 'PG_199'
# Relationship created: Client 'client_4929' BELONGS_TO PeerGroup 'PG_2643'
# Relationship created: Client 'client_4930' BELONGS_TO PeerGroup 'PG_965'
# Relationship created: Client 'client_4931' BELONGS_TO PeerGroup 'PG_097'
# Relationship created: Client 'client_4932' BELONGS_TO PeerGroup 'PG_675'
# Relationship created: Client 'client_4933' BELONGS_TO PeerGroup 'PG_3110'
# Relationship created: Client 'client_4934' BELONGS_TO PeerGroup 'PG_986'
# Relationship created: Client 'client_4935' BELONGS_TO PeerGroup 'PG_452'
# Relationship created: Client 'client_4936' BELONGS_TO PeerGroup 'PG_321'
# Relationship created: Client 'client_4937' BELONGS_TO PeerGroup 'PG_1562'
# Relationship created: Client 'client_4938' BELONGS_TO PeerGroup 'PG_054'
# Relationship created: Client 'client_4939' BELONGS_TO PeerGroup 'PG_1015'
# Relationship created: Client 'client_4940' BELONGS_TO PeerGroup 'PG_1539'
# Relationship created: Client 'client_4941' BELONGS_TO PeerGroup 'PG_381'
# Relationship created: Client 'client_4942' BELONGS_TO PeerGroup 'PG_251'
# Relationship created: Client 'client_4943' BELONGS_TO PeerGroup 'PG_2163'
# Relationship created: Client 'client_4944' BELONGS_TO PeerGroup 'PG_232'
# Relationship created: Client 'client_4945' BELONGS_TO PeerGroup 'PG_3389'
# Relationship created: Client 'client_4946' BELONGS_TO PeerGroup 'PG_952'
# Relationship created: Client 'client_4947' BELONGS_TO PeerGroup 'PG_1195'
# Relationship created: Client 'client_4948' BELONGS_TO PeerGroup 'PG_827'
# Relationship created: Client 'client_4949' BELONGS_TO PeerGroup 'PG_1602'
# Relationship created: Client 'client_4950' BELONGS_TO PeerGroup 'PG_553'
# Relationship created: Client 'client_4951' BELONGS_TO PeerGroup 'PG_1162'
# Relationship created: Client 'client_4952' BELONGS_TO PeerGroup 'PG_1545'
# Relationship created: Client 'client_4953' BELONGS_TO PeerGroup 'PG_975'
# Relationship created: Client 'client_4954' BELONGS_TO PeerGroup 'PG_2033'
# Relationship created: Client 'client_4955' BELONGS_TO PeerGroup 'PG_378'
# Relationship created: Client 'client_4956' BELONGS_TO PeerGroup 'PG_4758'
# Relationship created: Client 'client_4957' BELONGS_TO PeerGroup 'PG_1242'
# Relationship created: Client 'client_4958' BELONGS_TO PeerGroup 'PG_2323'
# Relationship created: Client 'client_4959' BELONGS_TO PeerGroup 'PG_765'
# Relationship created: Client 'client_4960' BELONGS_TO PeerGroup 'PG_1282'
# Relationship created: Client 'client_4961' BELONGS_TO PeerGroup 'PG_3468'
# Relationship created: Client 'client_4962' BELONGS_TO PeerGroup 'PG_2597'
# Relationship created: Client 'client_4963' BELONGS_TO PeerGroup 'PG_1445'
# Relationship created: Client 'client_4964' BELONGS_TO PeerGroup 'PG_681'
# Relationship created: Client 'client_4965' BELONGS_TO PeerGroup 'PG_052'
# Relationship created: Client 'client_4966' BELONGS_TO PeerGroup 'PG_528'
# Relationship created: Client 'client_4967' BELONGS_TO PeerGroup 'PG_1768'
# Relationship created: Client 'client_4968' BELONGS_TO PeerGroup 'PG_809'
# Relationship created: Client 'client_4969' BELONGS_TO PeerGroup 'PG_268'
# Relationship created: Client 'client_4970' BELONGS_TO PeerGroup 'PG_987'
# Relationship created: Client 'client_4971' BELONGS_TO PeerGroup 'PG_786'
# Relationship created: Client 'client_4972' BELONGS_TO PeerGroup 'PG_2602'
# Relationship created: Client 'client_4973' BELONGS_TO PeerGroup 'PG_149'
# Relationship created: Client 'client_4974' BELONGS_TO PeerGroup 'PG_349'
# Relationship created: Client 'client_4975' BELONGS_TO PeerGroup 'PG_1717'
# Relationship created: Client 'client_4976' BELONGS_TO PeerGroup 'PG_962'
# Relationship created: Client 'client_4977' BELONGS_TO PeerGroup 'PG_746'
# Relationship created: Client 'client_4978' BELONGS_TO PeerGroup 'PG_1341'
# Relationship created: Client 'client_4979' BELONGS_TO PeerGroup 'PG_1671'
# Relationship created: Client 'client_4980' BELONGS_TO PeerGroup 'PG_1459'
# Relationship created: Client 'client_4981' BELONGS_TO PeerGroup 'PG_2925'
# Relationship created: Client 'client_4982' BELONGS_TO PeerGroup 'PG_568'
# Relationship created: Client 'client_4983' BELONGS_TO PeerGroup 'PG_817'
# Relationship created: Client 'client_4984' BELONGS_TO PeerGroup 'PG_851'
# Relationship created: Client 'client_4985' BELONGS_TO PeerGroup 'PG_1358'
# Relationship created: Client 'client_4986' BELONGS_TO PeerGroup 'PG_2293'
# Relationship created: Client 'client_4987' BELONGS_TO PeerGroup 'PG_1191'
# Relationship created: Client 'client_4988' BELONGS_TO PeerGroup 'PG_1271'
# Relationship created: Client 'client_4989' BELONGS_TO PeerGroup 'PG_1626'
# Relationship created: Client 'client_4990' BELONGS_TO PeerGroup 'PG_2787'
# Relationship created: Client 'client_4991' BELONGS_TO PeerGroup 'PG_2518'
# Relationship created: Client 'client_4992' BELONGS_TO PeerGroup 'PG_1715'
# Relationship created: Client 'client_4993' BELONGS_TO PeerGroup 'PG_1207'
# Relationship created: Client 'client_4994' BELONGS_TO PeerGroup 'PG_192'
# Relationship created: Client 'client_4995' BELONGS_TO PeerGroup 'PG_1532'
# Relationship created: Client 'client_4996' BELONGS_TO PeerGroup 'PG_844'
# Relationship created: Client 'client_4997' BELONGS_TO PeerGroup 'PG_523'
# Relationship created: Client 'client_4998' BELONGS_TO PeerGroup 'PG_111'
# Relationship created: Client 'client_4999' BELONGS_TO PeerGroup 'PG_961'
# Relationship created: Client 'client_5000' BELONGS_TO PeerGroup 'PG_842'

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.79.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai) (0.27.0)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.10.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.12/site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/anaconda3/lib/python3.12/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Downloading openai-1.79.0-py3-none-any.whl (683 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 683.3/683.3 kB 8.8 MB/s eta 0:00:00
# Downloading jiter-0.10.0-cp312-cp312-macosx_11_0_arm64.whl (320 kB)
# Installing collected packages: jiter, openai
# Successfully installed jiter-0.10.0 openai-1.79.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# 2. Vector Database Setup (Chroma)
# ----------------------------------
#    * Ensure you have Chroma installed:  `pip install chromadb`
#    * Run a Chroma server, or use the in-memory option for this example.
embeddings = OpenAIEmbeddings()  #  Or any other embedding model

def create_chroma_collection(peer_group_definitions: pd.DataFrame):
    """
    Creates a Chroma collection and adds peer group descriptions.
    """
    chroma_client = chromadb.Client()  #  Or use: chromadb.PersistentClient(path="./chroma_db") for persistence
    collection = chroma_client.create_collection("peer_groups")

    documents = []
    metadatas = []
    ids = []
    for _, row in peer_group_definitions.iterrows():
        documents.append(row['description'])
        metadatas.append({'peer_group_id': row['peer_group_id']})
        ids.append(row['peer_group_id'])  # Use peer_group_id as the ID

    collection.add(
        documents=documents,
        metadatas=metadatas,
        ids=ids
    )
    return collection

import chromadb
chroma_collection = create_chroma_collection(peer_group_definitions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 5
#       1 # 2. Vector Database Setup (Chroma)
#       2 # ----------------------------------
#       3 #    * Ensure you have Chroma installed:  `pip install chromadb`
#       4 #    * Run a Chroma server, or use the in-memory option for this example.
# ----> 5 embeddings = OpenAIEmbeddings()  #  Or any other embedding model
#       7 def create_chroma_collection(peer_group_definitions: pd.DataFrame):
#       8     """
#       9     Creates a Chroma collection and adds peer group descriptions.
#      10     """
#
# NameError: name 'OpenAIEmbeddings' is not defined
